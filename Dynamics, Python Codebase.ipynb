# %% [markdown]
# # Codebase for "A Dynamic Theory of Deterrence and Compliance"
#
# Format: JupyterLab Notebook
#
# Kernel: Python3
#
# Code for all results and figures.
#
# *Note, to use this file user must first set the local path to store results of computation.*

# %%
""" 
    import libraries and set display options 
"""
import sys
import random as rn
import numpy as np
import math as math
import quantecon as qe
import scipy.stats as stats
import matplotlib.pyplot as plt

from numba import jit
from scipy.stats import norm
from scipy.stats import binom
from scipy.stats import truncnorm
from scipy.stats import entropy
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from mpl_toolkits.axes_grid1.inset_locator import InsetPosition


path = 

# aesthetic settings
import warnings
sys.setswitchinterval(1500)
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ### Main Functions Called
#
# The following cell contains the main functions called in the main codebase.

# %%
""" 
    functions used by simulations 
"""

# apprehension function, min catch
@jit(nopython=True)
def Apprehend(v, R):
    γ = 0.80 
    if v == 0:
        prob_a = γ
    else:
        prob_a = γ*min(1, R/v)
    return prob_a

# apprehension function, exponential
@jit(nopython=True)
def Apprehend_exp(v, R):
    γ = 0.80  
    ϵ = 4
    if v == 0:
        prob_a = γ
    else:
        prob_a = γ*(1-(1/pow(ϵ,(R/v))))
    return prob_a

# create a 'criminal opportunity'
def Opportunity():
    lower, upper = 0, 1
    ḡ , σ = 0.6, 0.2
    return max(0, np.random.normal(ḡ, σ)) 

# create a distribution of 'criminal opportunities'
@jit(nopython=True)
def Criminal_opps(μ, σ, agents, T):
    g = np.zeros((T,agents))
    for i in range(T):
        g[i] = [max(0, np.random.normal(ḡ, σ)) for agent in range(agents)]
    return g

# create a distribution of 'criminal opportunities'
@jit(nopython=True)
def Criminal_opps_uniform(μ, σ, agents, T):
    g = np.zeros((T,agents))
    for i in range(T):
        g[i] = [max(0, np.random.uniform(0, 1.2)) for agent in range(agents)]
    return g

def Simulation(criminal_opps, R, F, Z):
# agent priors
    α,β = 1, 0.25
    init_period = 100
# tracking arrays for endogenous variables of interest
    a_t,v_t, g_t = [], [], []
# seed for priors
    append_v = v_t.append
    append_a = a_t.append
    append_g = g_t.append
    for t in range(Z):
        v = np.random.randint(1,agents)
        a = np.random.randint(0,v)
        append_v(v)
        append_a(a)
# main sim loop, starts at T = 500   
    for t in range(len(criminal_opps)):
        a,v,g = 0,0,0
        q = (α + np.sum(a_t[-Z:]))/(α + β + np.sum(v_t[-Z:]))
        for g_i in criminal_opps[t]:
            if  q <= g_i/F:
                v = v + 1
                g = g + g_i
        a = stats.binom.rvs(v, Apprehend(v, R))
        append_v(v)
        append_a(a)
        append_g(g)
    
    return np.array(v_t[init_period+Z:]), np.array(a_t[init_period+Z:]), np.array(g_t[init_period+Z:])

def Simulation_exp(criminal_opps, R, F, Z):
# agent priors
    α,β = 1, 0.25
    init_period = 100
# tracking arrays for endogenous variables of interest
    a_t,v_t, g_t = [], [], []
# seed for priors
    append_v = v_t.append
    append_a = a_t.append
    append_g = g_t.append
    for t in range(Z):
        v = np.random.randint(1,agents)
        a = np.random.randint(0,v)
        append_v(v)
        append_a(a)
# main sim loop, starts at T = 500   
    for t in range(len(criminal_opps)):
        a,v,g = 0,0,0
        q = (α + np.sum(a_t[-Z:]))/(α + β + np.sum(v_t[-Z:]))
        for g_i in criminal_opps[t]:
            if  q <= g_i/F:
                v = v + 1
                g = g + g_i
        a = stats.binom.rvs(v, Apprehend_exp(v, R))
        append_v(v)
        append_a(a)
        append_g(g)
    
    return np.array(v_t[init_period+Z:]), np.array(a_t[init_period+Z:]), np.array(g_t[init_period+Z:])

def Simulation_het_q(criminal_opps, R, F, Z):
# agent priors
    α,β = 1, 0.25
    init_period = 100
# tracking arrays for endogenous variables of interest
    a_t,v_t, g_t = [], [], []
# seed for priors
    append_v = v_t.append
    append_a = a_t.append
    append_g = g_t.append
    for t in range(Z):
        v = np.random.randint(1,agents)
        a = np.random.randint(0,v)
        append_v(v)
        append_a(a)
# main sim loop, starts at T = 500   
    for t in range(len(criminal_opps)):
        a,v,g = 0,0,0
        q = (α + np.sum(a_t[-Z:]))/(α + β + np.sum(v_t[-Z:]))
        for g_i in criminal_opps[t]:
            q_i = q + np.random.uniform(-0.2,0.2)
            if q_i > 1:
                q_i = 1
            if q_i < 0:
                q_i = 0
            if  q_i <= g_i/F:
                v = v + 1
                g = g + g_i
        a = stats.binom.rvs(v, Apprehend(v, R))
        append_v(v)
        append_a(a)
        append_g(g)
    
    return np.array(v_t[init_period+Z:]), np.array(a_t[init_period+Z:]), np.array(g_t[init_period+Z:])

def Crackdown(criminal_opps, BE, RGB, RBB, F, Z):
# agent priors
    T = len(criminal_opps)
    α,β = 1, 0.25
    r = RGB
# tracking arrays for endogenous variables of interest
    a_t,v_t, g_t, r_t = [], [], [],[]
# seed for priors
    append_v = v_t.append
    append_a = a_t.append
    append_g = g_t.append
    append_r = r_t.append
    for t in range(Z):
        v = np.random.randint(1,agents)
        a = stats.binom.rvs(v, Apprehend(v, r))
        append_v(v)
        append_a(a)
        append_r(r)
# main sim loop, starts at T = 500   
    for t in range(len(criminal_opps)):
        if t > 0:
            if v >= BE:
                r = RBB
            else:
                r = RGB 
        else:
            r = RGB
        a,v,g = 0,0,0
        q = (α + np.sum(a_t[-Z:]))/(α + β + np.sum(v_t[-Z:]))
        for g_i in criminal_opps[t]:
            if  q <= g_i/F:
                v = v + 1
                g = g + g_i
        a = stats.binom.rvs(v, Apprehend(v, r))
        append_v(v)
        append_a(a)
        append_g(g)
        append_r(r)
    
    return np.array(v_t[-T:]), np.array(a_t[-T:]), np.array(g_t[-T:]), np.array(r_t[-T:])

# %% [markdown]
# # State Space Production and Transition Matrices
#
# The first function produces, for a given number of agents, the State Space of the model ($\boldsymbol{Z}$) from Section 2.3.
#
# The second function produces the conditional probabilities establishing Proposition 3 on page 11.
#
# The third function takes the probabilities from above as arguments and produces the complete transition matrix for the model ($\boldsymbol{T}$ from page 9).

# %%
"""
    Produce State space
        parameters: agents
        returns: S, Shat, s
"""
def State_space(agents: int):
    w = np.sum(np.arange(1,agents+2))
    s = np.zeros(w, dtype=int)
    R̂ = np.empty(w, dtype=object)
    Ŝ = np.empty(w, dtype=object)
    S = [[(i,j) for j in range(agents+1)] for i in range(agents+1)]
    l=0

    for i in range(agents+1):
        for j in range(agents+1):
            if i >= j:
                k = np.arange(i+1)
                S[i][j] = (i,j)
                Ŝ[l] = (1+i-j+np.sum(k),i,j)
                s[l] = 1+i-j+np.sum(k)
                l=l+1
            if i < j:
                S[i][j] = (i,0)
    Ŝ = sorted(Ŝ, key=lambda tup: tup[0])
    s = sorted(s)
    return S, Ŝ, s

"""
    Produce M1 and M2 matrices to speed analysis
        parameters: agents, F
        returns: M1, M2
"""

def TM_matrices(agents: int, F:float):
# parameters
    ḡ = 0.60
    σ = 0.20
    α,β = 1,0.25
# tracking arrays/vectors
    S, Ŝ, s = State_space(agents)
    w = len(s)
    A = np.zeros(w)
    π = np.zeros(w)
    M1 = np.zeros((w,w))
    M2 = np.zeros((w,w))
    
# main loop
    for state_1 in range(w):
        v = Ŝ[state_1][1]
        a = Ŝ[state_1][2]
        q = (α + a)/(α + β + v)
        π[state_1] = 1 - norm.cdf(F*q-ḡ,0,σ)
        for state_2 in range(w):
            v = Ŝ[state_2][1]
            a = Ŝ[state_2][2]
            v̂ = math.factorial(v)
            â = math.factorial(a)
            d̂ = math.factorial(v-a)
            M1[state_1,state_2] = binom.pmf(v,agents,π[state_1])
            M2[state_1,state_2] = v̂/(â*d̂)
    return M1, M2

""" 
    Produce transition matrix for all s to s'
        s = numbered states
"""
def Transition_matrix(agents: int, M1, M2, R: int, F:float, switch:bool):
# tracking arrays/vectors
    S, Ŝ, s = State_space(agents)
    w = len(s)
    T̂ = np.zeros((w,w))
    
# main loop
    for state_1 in range(w):
        for state_2 in range(w):
            v = Ŝ[state_2][1]  
            a = Ŝ[state_2][2]
            d = v - a
            if switch:
                Â = Apprehend(v, R[state_1])
            else:
                Â = Apprehend(v, R[state_1])
            M3 = math.pow(Â, a)*math.pow(1-Â, d)
            T̂[state_1,state_2] = M1[state_1,state_2]*M2[state_1,state_2]*M3
    return T̂

def Compute_cost(agents: int, R:int , F:float):
# parameters
    δ, λ = 2, 5
    ḡ = 0.60
    σ = 0.20
    α,β = 1,0.25
# tracking arrays/vectors
    S, Ŝ, s = State_space(agents)
    w = len(s)
    A = np.zeros(w)
    π = np.zeros(w)
    Ĉ = np.zeros(w)
    
# main loop
    for state in range(w):
        v = Ŝ[state][1]
        a = Ŝ[state][2]
        q = (α + a)/(α + β + v)
        π[state] = 1 - norm.cdf(F*q-ḡ, 0, σ)
        A[state] = Apprehend(π[state]*agents, R[state])
        Ĉ[state] = δ*R[state] + (λ-1)*agents*π[state] + agents*F*π[state]*A[state]
    return Ĉ

# %%
""" 
    baseline model parameters for kernel
    
"""
# main parameters
agents = 100
Z = 1, 2

# distribution parameters
ḡ , σ = 0.6 , 0.2

# Bayesian priors
α, β = 1, 0.25

# costs
ρ, λ = 2 , 5

# domain of analysis for policy
F = 1
R_low, R_high = 0, agents+1

# benchmarking parameters
block = 50000
checks, C = 5, 0.01

# %% [markdown]
# ### Table A.1
#
# First cell produces the transition matrix of the finite regular Markov chain. Using the TM we produce the associated Markov chain (MC) and its associated stationary distribution ($\bar{S}$).
#
# The following cell produces the results from Table A.1 by comparing the estimated distribution of violations ($\boldsymbol{\hat{D}}$) against $\bar{S}$.

# %%
""" 
    produce TM and SD in order to benchmark simulation
            state space for:
                    N = 50, Z=1
"""
# paramaters for benchmarking exercise
switch = True
agents, Z = 50, 1
R_low, R_high = 0, agents+1
# variables used for benchmark exercise
R = np.ones(np.sum(np.arange(1,agents+2)), dtype=int)

# "control" variables
ex_v = np.zeros(R_high-R_low)
ex_a = np.zeros(R_high-R_low)
std_v = np.zeros(R_high-R_low)
# vectors, arrays, storage objects
S̄ = np.empty(R_high-R_low, dtype=object)
V̂ = np.empty(R_high-R_low, dtype=object)
Â = np.empty(R_high-R_low, dtype=object)
Ĉ = np.empty(R_high-R_low, dtype=object)
MC = np.empty(R_high-R_low, dtype=object)

# create the ordered state space
S, Ŝ, s = State_space(agents)
max_v = np.zeros(len(s))
max_a = np.zeros(len(s))
for state in range(len(s)):
    max_v[state] = Ŝ[state][1]
    max_a[state] = Ŝ[state][2]

# create transition matrices
M1 , M2 = TM_matrices(agents, F)

# main loop
for r in range(R_low, R_high):
    index = 0
    a, v = 0, 0
    R.fill(r)
    TM = Transition_matrix(agents, M1, M2, R, F, switch)
    MC[r] = qe.MarkovChain(TM)
    S̄[r] = MC[r].stationary_distributions
    V̂[r] = S̄[r]*max_v
    Â[r] = S̄[r]*max_a
    ex_v[r] = np.sum(V̂[r])
    ex_a[r] = np.sum(Â[r])
    std_v[r] = np.std(V̂[r])

# %%
"""
        Benchmarking: Run simulation to converge for comparison with results from cell above
                        
                        Note: need to set r = 5, 21, 45 to reproduce Table A.1
"""
runs, block = 1000, 50000
agents = 50
Z = 1
r = 45
C, checks = 0.01, 5
TEST = np.zeros(runs)

# translate SD from TM into same format as DD1
#      DD1 runs from 0 to agents+1
#      state space of SD is much larger
DD3 = np.zeros(agents+1)
for i in Ŝ:
    DD3[i[1]] = DD3[i[1]] + S̄[r][0][i[0]-1]

time_to_converge = 0
for run in range(runs):
    v_μ = 0
    converged, passed = False, 0
    DD1 = np.zeros(agents+1)
    DD2 = np.zeros(agents+1)
    criminal_opps = Criminal_opps(ḡ,σ,agents,block)
    v_t, a_t, g_t = Simulation(criminal_opps,r,F,Z)
    v, a, g = 0, 0, 0
    v = np.append(v, v_t)
    a = np.append(a, a_t)
    g = np.append(g, g_t)
    for i in v:
        DD1[i] = DD1[i] + 1
    while not converged:
        time_to_converge = time_to_converge + 1
        criminal_opps = Criminal_opps(ḡ,σ,agents,block)
        v_t, a_t, g_t = Simulation(criminal_opps,r,F,Z)
        v = np.append(v, v_t)
        a = np.append(a, a_t)
        g = np.append(g, g_t)
        for i in v:
            DD2[i] = DD2[i] + 1    
        if np.abs(np.sum((DD2/np.sum(DD2)) - (DD1/np.sum(DD1)))) < C:
            passed = passed + 1
            if passed > checks:
                converged = True
        DD1 = DD2[:]
    DD1 = DD1/np.sum(DD1)
    TEST[run] = np.sum(np.abs(DD1-DD3))
    
    
np.set_printoptions(precision=4)
x = np.mean(TEST)
y = np.std(TEST)
z = np.max(TEST)

print("%0.4f" % x),print("%0.4f" % y),print("%0.4f" % z),print("%0.4f" % ((time_to_converge+1)/1000))

# %% [markdown]
# ## Figure A.1:  Summarizing full information static model

# %%
"""
    compute number of expected equilibria as a function of v
"""
agents = 100

prob_eq = np.zeros((agents+1,agents+1))
ex_eq_v = np.zeros(agents+1)
ex_eq_good = np.zeros(agents+1)
ex_eq_bad = np.zeros(agents+1)
ex_eq_other = np.zeros(agents+1)

for R in range(agents+1):
    for v in range(agents+1):
        N = math.factorial(agents)/(math.factorial(v)*math.factorial(agents-v))
        A1 = 1 - (norm.cdf(Apprehend(v, R)*F,ḡ,σ))
        A2 = norm.cdf(Apprehend(v+1, R)*F,ḡ,σ)
        prob_eq[R][v] = N*math.pow(A1,v)*math.pow(A2,agents-v)
    ex_eq_good[R] = np.sum(prob_eq[R,:30])
    ex_eq_bad[R] = np.sum(prob_eq[R,70:])
    ex_eq_other[R] = np.sum(prob_eq[R,30:70])
    prob_norm = np.zeros(agents+1)
    prob_norm = prob_eq[R]/np.sum(prob_eq[R])
    ex_eq_v[R] = np.sum(prob_norm[0:30]*np.arange(30)*ex_eq_good[R])+ np.sum(prob_norm[31:70]*np.arange(31,70)*ex_eq_other[R])+np.sum(prob_norm[71:]*np.arange(71,101)*ex_eq_bad[R])
    
np.save(path+'fig31_prob_eq.npy', prob_eq)   
np.save(path+'fig31_ex_eq_v.npy', ex_eq_v)   
np.save(path+'fig31_ex_good.npy', ex_eq_good)
np.save(path+'fig31_ex_bad.npy', ex_eq_bad)
np.save(path+'fig31_ex_other.npy', ex_eq_other)

# %% [markdown]
# ### Visualization

# %%
prob_eq = np.load(path+'fig31_prob_eq.npy')
ex_eq_v = np.load(path+'fig31_ex_eq_v.npy')
ex_eq_good = np.load(path+'fig31_ex_good.npy')
ex_eq_bad = np.load(path+'fig31_ex_bad.npy')
ex_eq_other = np.load(path+'fig31_ex_other.npy')
agents = len(prob_eq)-1

fig = plt.figure(figsize=(12,8),tight_layout=True,dpi=150)
x = np.arange(0,agents+1)
x1 = np.arange(0,30)
x2 = np.arange(70,agents+1)
x3 = np.arange(30,71)
gs = fig.add_gridspec(4, 1)
ax1 = fig.add_subplot(gs[:2, 0])
ax2 = fig.add_subplot(gs[2, 0])
ax3 = fig.add_subplot(gs[3, 0])

ax1.set_title('Panel 1: Probability of an equilibrium with $v$ violations, $R=39$', fontsize= 'small')
ax1.set_xlabel('Number of violations (v)', fontsize= 'small')
ax1.yaxis.label.set_size(11)
ax1.set_xticks(np.arange(0,agents+10,10))
ax1.set_yticks(np.arange(0, 0.25,.05))
ax1.set_xlim([0, agents])
ax1.set_ylim([0, 0.20])
ax1.plot(x, prob_eq[39], color='k', linestyle='solid',linewidth=0.5)
ax1.fill_between(x1, prob_eq[39,:30], color='lightgray', alpha=0.2)
ax1.fill_between(x3, prob_eq[39,30:71], color='dimgray', alpha=0.4)
ax1.fill_between(x2, prob_eq[39,70:], color='gray', alpha=0.8)
ax1.annotate('Probability of bad equilibrium ($v \geq 70$)', xy=(84, .065), xytext=(70, .12), fontsize=11,
            arrowprops=dict(facecolor='black', width=0.15, shrink=0.0005))
ax1.annotate('Probability of good equilibrium ($v \leq 30$)', xy=(13, .10), xytext=(10, .15), fontsize=11,
            arrowprops=dict(facecolor='black', width=0.15, shrink=0.0005))
ax1.annotate('Probability of other equilibrium ($30 < v < 70$)', xy=(55, .009), xytext=(30, .05), fontsize=11,
            arrowprops=dict(facecolor='black', width=0.15, shrink=0.0005))

ax2.set_title('Panel 2: Expected number of equilibria as a function of R', fontsize= 'small')
ax2.set_xlabel('Deterrent resources (R)', fontsize='small')
ax2.set_xticks(np.arange(0,agents+10,10))
ax2.set_xlim([0, agents])
ax2.set_yticks(np.arange(0,2.75, 0.5))
ax2.set_ylim([0,2.5])
ax2.plot(x, ex_eq_good+ex_eq_bad+ex_eq_other, color='k', linestyle='solid',linewidth=0.5,  
         label='# of equilibria')
ax2.plot(x, ex_eq_good, color='k', linestyle='dashed',linewidth=0.5, marker="o", markevery=5, ms=5, markerfacecolor='none',
         label='# of good')
ax2.plot(x, ex_eq_bad, color='k', linestyle='dashdot',linewidth=0.5, marker="x", markevery=5, ms=5,
         label='# of bad')
ax2.plot(x, ex_eq_other, color='k', linestyle='dotted',linewidth=0.5,
         label='# of other')
ax2.annotate('# eq', xy=(45, 2.0), fontsize=10)
ax2.annotate('# good eq (o)', xy=(4, 0.25), fontsize=10)
ax2.annotate('# other eq', xy=(33, 0.25), fontsize=10)
ax2.annotate('# bad eq (x)', xy=(2, 1.2), fontsize=10)

ax3.set_title('Panel 3: Expected number of violations weighted by probability of observing each equilibrium', fontsize= 'small')
ax3.set_xlabel('Deterrent resources (R)', fontsize='small')
ax3.set_xticks(np.arange(0,agents+10,10))
ax3.set_xlim([0, agents])
ax3.set_yticks(np.arange(0,agents+10, 20))
ax3.set_ylim([0,agents])
ax3.plot(x, ex_eq_v, color='k', linestyle='solid',linewidth=0.5, 
         label='Expected violations')
ax3.legend(loc='best', fontsize=11, frameon=False)

#plt.savefig(path+);

# %%
"""
    compute number of expected equilibria as a function of v
            Note: calculation done for v = 10, 35, 50
"""
agents = 100
e_v_10 = np.zeros(agents+1)
e_v_35 = np.zeros(agents+1)
e_v_50 = np.zeros(agents+1)

for v in range(agents+1):
    e_v_10[v] = agents*(1 - (norm.cdf(Apprehend(v, 10)*F,ḡ,σ)))
    e_v_35[v] = agents*(1 - (norm.cdf(Apprehend(v, 35)*F,ḡ,σ)))
    e_v_50[v] = agents*(1 - (norm.cdf(Apprehend(v, 50)*F,ḡ,σ)))

np.save(path+'fig32_e_v_10.npy', e_v_10)   
np.save(path+'fig32_e_v_35.npy', e_v_35)   
np.save(path+'fig32_e_v_50.npy', e_v_50)

# %% [markdown]
# ### Visualization

# %%
"""
    compute number of expected equilibria as a function of v
"""
e_v_10 = np.load(path+'fig32_e_v_10.npy')
e_v_35 = np.load(path+'fig32_e_v_35.npy')
e_v_50 = np.load(path+'fig32_e_v_50.npy')

agents = len(e_v_0)
x = np.arange(0,agents)
intersections_10 = []
intersections_35 = []
intersections_50 = []

# Find intersections

    if int(e_v_10[i]) == x[i]:
        intersections_10.append(i)
        
for i in range(len(e_v_35)):
    if int(e_v_35[i]) == x[i]:
        intersections_35.append(i)

for i in range(len(e_v_50)):
    if int(e_v_50[i]) == x[i]:
        intersections_50.append(i)

fig, ax1 = plt.subplots(figsize=(10,6),tight_layout=True,dpi=150)

ax1.set_xlabel('Number of violations ($v_t$)', fontsize= 'large')
ax1.set_ylabel('$E(v_{t+1}|v_t)$', fontsize= 'medium')
ax1.yaxis.label.set_size(11)
ax1.set_xticks(np.arange(0,agents+10, 10))
ax1.set_yticks(np.arange(0,agents+10,10))
ax1.set_xlim([0, agents])
ax1.set_ylim([0, agents])
ax1.vlines(intersections_10[0], ymin=0, ymax=x[intersections_10[0]], linestyle='dotted', linewidth=0.5)
ax1.vlines(intersections_35[0], ymin=0, ymax=x[intersections_35[0]], linestyle='dotted', linewidth=0.5)
ax1.vlines(intersections_35[1], ymin=0, ymax=x[intersections_35[1]], linestyle='dotted', linewidth=0.5)
ax1.vlines(intersections_35[2], ymin=0, ymax=x[intersections_35[2]], linestyle='dotted', linewidth=0.5)
ax1.text(8,90, '$E(v_{t+1}|v_t, R=10)$', fontsize=11)
ax1.text(45,80, '$E(v_{t+1}|v_t, R=35)$', fontsize=11)
ax1.text(65,40, '$E(v_{t+1}|v_t, R=50)$', fontsize=11)
ax1.text(15,1, '15', fontsize=11)
ax1.text(45,1, '45', fontsize=11)
ax1.text(90,1, '92', fontsize=11)
ax1.text(99,1, '99', fontsize=11)
ax1.plot(x, x, color='k', linestyle='solid',linewidth=0.5)
ax1.plot(x, e_v_10, color='k', linestyle='dashed',linewidth=0.5,
        label='$E(v_{t+1}|v_t, R=10)$')
ax1.plot(x, e_v_35, color='k', linestyle='dashed',linewidth=0.5,
        label='$E(v_{t+1}|v_t, R=35)$')
ax1.plot(x, e_v_50, color='k', linestyle='dashed',linewidth=0.5,
        label='$E(v_{t+1}|v_t, R=50)$')

#plt.savefig(path+);

# %% [markdown]
# ## Fig 3.1: Raw time series of violations for chosen values of R. [5x2 panels]
#
# Note, choosen values of R: 37, 40, 41, 42, 46

# %%
"""
        Fig 3.1: time path of 'raw data'
            Note: Set T = block for plotting purposes
"""
agents, Z = 100, 2

fig = plt.figure(figsize=(12,6),tight_layout=True,dpi=150)
gs = fig.add_gridspec(5, 3)
ax1 = fig.add_subplot(gs[0, :-1])
ax2 = fig.add_subplot(gs[1, :-1])
ax3 = fig.add_subplot(gs[2, :-1])
ax4 = fig.add_subplot(gs[3, :-1])
ax5 = fig.add_subplot(gs[4, :-1])
iax1 = fig.add_subplot(gs[0, -1])
iax2 = fig.add_subplot(gs[1, -1])
iax3 = fig.add_subplot(gs[2, -1])
iax4 = fig.add_subplot(gs[3, -1])
iax5 = fig.add_subplot(gs[4, -1])

illustrative_run = Criminal_opps(ḡ, σ, agents, 6000)
v, a, g, q = Simulation(illustrative_run,37,F,Z)
ax1.set_xlim([0, 5000])
ax1.set_ylim([0, agents])
ax1.set_xticks(np.arange(0, 5000+250, 500))
ax1.plot(v[500:6000],color='k',linewidth=0.10, label="violations")
plt.xticks(np.arange(0, agents))
plt.xlim(0,agents)
iax1.set_xlim([0, 0.15])
iax1.set_ylim([0,agents])
iax1.set_xticks(np.arange(0,0.20,0.05))
iax1.set(ylabel='R = 37')
iax1.yaxis.label.set_size(10)
iax1.hist(v[1000:6000], color='gray', orientation ='horizontal', density=True, lw=0, bins=25)

illustrative_run = Criminal_opps(ḡ, σ, agents, 6000)
v, a, g, q = Simulation(illustrative_run,40,F,Z)
ax2.set_xlim([0, 5000])
ax2.set_ylim([0, agents])
ax2.set_xticks(np.arange(0, 5000+500, 500))
ax2.plot(v[500:6000],color='k',linewidth=0.10, label="violations")
plt.xticks(np.arange(0, agents))
plt.xlim(0,agents)
iax2.set_xlim([0, 0.15])
iax2.set_ylim([0,agents])
iax2.set_xticks(np.arange(0,0.20,0.05))
iax2.set(ylabel='R = 40')
iax2.yaxis.label.set_size(10)
iax2.hist(v[1000:6000], color='gray', orientation ='horizontal', density=True, lw=0, bins=25)

illustrative_run = Criminal_opps(ḡ, σ, agents, 6000)
v, a, g, q = Simulation(illustrative_run,41,F,Z)
ax3.set(ylabel='violations')
ax3.yaxis.label.set_size(12)
ax3.set_xlim([0, 5000])
ax3.set_ylim([0, agents])
ax3.set_xticks(np.arange(0, 5000+250, 500))
ax3.plot(v[500:6000],color='k',linewidth=0.10, label="violations")
plt.xticks(np.arange(0, agents))
plt.xlim(0,agents)
iax3.set_xlim([0, 0.15])
iax3.set_ylim([0,agents])
iax3.set_xticks(np.arange(0,0.20,0.05))
iax3.set(ylabel='R = 41')
iax3.yaxis.label.set_size(10)
iax3.hist(v[1000:6000], color='gray', orientation ='horizontal', density=True, lw=0, bins=25)

illustrative_run = Criminal_opps(ḡ, σ, agents, 6000)
v, a, g, q = Simulation(illustrative_run,42,F,Z)
ax4.set_xlim([0, 5000])
ax4.set_ylim([0, agents])
ax4.set_xticks(np.arange(0, 5000+250, 500))
ax4.plot(v[500:6000],color='k',linewidth=0.10, label="violations")
plt.xticks(np.arange(0, agents))
plt.xlim(0,agents)
iax4.set_xlim([0, 0.15])
iax4.set_ylim([0,agents])
iax4.set_xticks(np.arange(0,0.20,0.05))
iax4.set(ylabel='R = 42')
iax4.yaxis.label.set_size(10)
iax4.hist(v[1000:6000], color='gray', orientation ='horizontal', density=True, lw=0, bins=25)

illustrative_run = Criminal_opps(ḡ, σ, agents, 6000)
v, a, g, q = Simulation(illustrative_run,46,F,Z)
ax5.set(xlabel='Tick (T = 0, ..., 5000)')
ax5.xaxis.label.set_size(10)
ax5.set_xlim([0, 5000])
ax5.set_ylim([0, agents])
ax5.set_xticks(np.arange(0, 5000+250, 500))
ax5.plot(v[500:6000],color='k',linewidth=0.10, label="violations")
plt.xticks(np.arange(0, agents))
plt.xlim(0,agents)
iax5.set_xlim([0, 0.15])
iax5.set_ylim([0,agents])
iax5.set(ylabel='R = 46')
iax5.yaxis.label.set_size(10)
iax5.set_xticks(np.arange(0,0.20,0.05))
iax5.set(xlabel='frequency distribution')
iax5.xaxis.label.set_size(10)
iax5.hist(v[1000:6000], color='gray', orientation ='horizontal', density=True, lw=0, bins=25)

#plt.savefig(path+);

# %% [markdown]
# ## Fig 3.2 The durability of crime waves and perceptions of apprehension.[2x1 panels]
#
# Note, user needs to supply appropriate time series selection.

# %%
data = np.loadtxt(path+"fig32_data.csv", delimiter=',', dtype=float)
violations = np.zeros(len(data))
arate = np.zeros(len(data))
p = np.zeros(len(data))
q = np.zeros(len(data))
j = 0

for i in data:
    violations[j] = i[0]
    arate[j] = i[1]
    p[j] = i[2]
    q[j] = i[3]
    j = j+1

fig = plt.figure(figsize=(12,8),tight_layout=True,dpi=150)
gs = fig.add_gridspec(2, 1)
ax1 = fig.add_subplot(gs[:1, 0])
ax2 = fig.add_subplot(gs[1:, 0])

ax1.set_title('Panel 1: Illustrative time path of violations and apprehenshion rate')
ax1.set(ylabel='Violations')
ax1i = ax1.twinx()
ax1.set_xticks(np.arange(0,len(violations), 50))
ax1.set_yticks(np.arange(0,agents, 10))
ax1.set_xlim([0, len(violations)])
ax1.set_ylim([0, agents])
ax1.plot(violations, color='k', linestyle='solid',linewidth=0.75)
ax1i.plot(arate, color ='k', linestyle='dotted',linewidth=0.75)
ax1.hlines(50, xmin=0, xmax=len(violations), linestyle='dashed',linewidth=0.75) 
ax1.vlines(108, ymin=0, ymax=agents, linestyle='dashed',linewidth=0.75) 
ax1.vlines(372, ymin=0, ymax=agents, linestyle='dashed',linewidth=0.75)
ax1.text(50,45,'BE=50',color='k',fontsize='12')
ax1.text(200,70,'Violations',color='k',fontsize='12')
ax1.text(200,15,'Apprehension rate',color='k',fontsize='12')
ax1i.set(ylabel='Apprehension rate ($a/v$)')
ax1i.set_xticks(np.arange(0,len(violations), 50))
ax1i.set_yticks(np.arange(0, 1.1, 0.1))
ax1i.set_xlim([0, len(violations)])
ax1i.set_ylim([0, 1])


ax2.set_title('Panel 2: Illustrative time path of p and q')
ax2.set(ylabel='Probabilities (p, q)')
ax2.set_xticks(np.arange(0,len(p), 50))
ax2.set_yticks(np.arange(0,1.1, 0.1))
ax2.set_xlim([0, len(p)])
ax2.set_ylim([0, 1])
ax2.plot(p, color ='k', linestyle='solid',linewidth=0.75, label = 'Objective prob (p)')
ax2.plot(q, color ='k', linestyle='dotted',linewidth=0.75, label = 'Subjective prob (q)')
ax2.vlines(108, ymin=0, ymax=1, linestyle='dashed',linewidth=0.75) 
ax2.vlines(372, ymin=0, ymax=1, linestyle='dashed',linewidth=0.75)
ax2.legend(loc='lower right', fontsize=12, frameon=False)

#plt.savefig(path+);

# %% [markdown]
# ### Figure 3.3: Persistence of violations in each regime. [2x1 panels]

# %%
"""
        Persistence of the attractors
            Note: 
"""
compliant_bin = 50
run_length = 2000104

chosen_r = [39,40,41,42,43]

log_ED_compliant = []
log_ED_unruly = []
frac_c = np.zeros(5)
frac_u = np.zeros(5)
mean_CB = np.zeros(5)
mean_UB = np.zeros(5)
sd_CB = np.zeros(5)
sd_UB = np.zeros(5)

criminal_opps = Criminal_opps(ḡ, σ, agents, run_length)
v, a, g, q = 0, 0, 0, 0
v, a, g, q = Simulation(criminal_opps,chosen_r[0],F,Z)
v_39 = v
state = []
compliant_v = []
unruly_v = []
tm = np.zeros((2,2))
for violation in v:
    if violation < compliant_bin:
        state.append(0)
        compliant_v.append(violation)
    elif violation >= compliant_bin:
        state.append(1)
        unruly_v.append(violation)
                
for i in range(len(state)-1):
    tm[state[i]][state[i+1]] = tm[state[i]][state[i+1]] + 1
    
prob_c = len(compliant_v)/len(state)
prob_u = len(unruly_v)/len(state)
frac_c[0] = prob_c
frac_u[0] = prob_u
prob_cc = tm[0][0]/np.sum(tm[0])
prob_cu = tm[0][1]/np.sum(tm[0])
prob_uc = tm[1][0]/np.sum(tm[1])
prob_uu = tm[1][1]/np.sum(tm[1])
if math.isnan(prob_cc):
    length_compliant = str(1)
elif prob_cc == 1:
    length_compliant = 'infinity'
else:
    length_compliant = str(math.floor(1/(1-prob_cc)))
    log_ED_compliant.append(np.log(math.floor(1/(1-prob_cc))))
if math.isnan(prob_uu):
    length_unruly = str(1)
elif prob_uu == 1:
    length_unruly = 'infinity'
else:
    length_unruly = str(math.floor(1/(1-prob_uu)))
    log_ED_unruly.append(np.log(math.floor(1/(1-prob_uu))))
if len(compliant_v) != 0:
    mode_compliant = stats.mode(compliant_v)[0][0]
    sd_compliant = str(round(np.std(compliant_v),2))
    mean_compliant = str(round(np.mean(compliant_v),2))
    mean_CB[0] = np.mean(compliant_v)
    sd_CB[0] = np.std(compliant_v)
else:
    mode_compliant = np.nan
    sd_compliant = str(np.nan)
    mean_compliant = str(np.nan)
if len(unruly_v) != 0:
    mode_unruly = stats.mode(unruly_v)[0][0]
    sd_unruly = str(round(np.std(unruly_v),2))
    mean_unruly = str(round(np.mean(unruly_v),2))
    mean_UB[0] = np.mean(unruly_v)
    sd_UB[0] = np.std(unruly_v)
else:
    mode_unruly = np.nan
    sd_unruly = str(np.nan)
    mean_unruly = str(np.nan)

criminal_opps = Criminal_opps(ḡ, σ, agents, run_length)
v, a, g, q = 0, 0, 0, 0
v, a, g, q = Simulation(criminal_opps,chosen_r[1],F,Z)
v_40 = v
state = []
compliant_v = []
unruly_v = []
tm = np.zeros((2,2))
for violation in v:
    if violation < compliant_bin:
        state.append(0)
        compliant_v.append(violation)
    elif violation >= compliant_bin:
        state.append(1)
        unruly_v.append(violation)
                
for i in range(len(state)-1):
    tm[state[i]][state[i+1]] = tm[state[i]][state[i+1]] + 1
    
prob_c = len(compliant_v)/len(state)
prob_u = len(unruly_v)/len(state)
frac_c[1] = prob_c
frac_u[1] = prob_u
prob_cc = tm[0][0]/np.sum(tm[0])
prob_cu = tm[0][1]/np.sum(tm[0])
prob_uc = tm[1][0]/np.sum(tm[1])
prob_uu = tm[1][1]/np.sum(tm[1])
if math.isnan(prob_cc):
    length_compliant = str(1)
elif prob_cc == 1:
    length_compliant = 'infinity'
else:
    length_compliant = str(math.floor(1/(1-prob_cc)))
    log_ED_compliant.append(np.log(math.floor(1/(1-prob_cc))))
if math.isnan(prob_uu):
    length_unruly = str(1)
elif prob_uu == 1:
    length_unruly = 'infinity'
else:
    length_unruly = str(math.floor(1/(1-prob_uu)))
    log_ED_unruly.append(np.log(math.floor(1/(1-prob_uu))))
if len(compliant_v) != 0:
    mode_compliant = stats.mode(compliant_v)[0][0]
    sd_compliant = str(round(np.std(compliant_v),2))
    mean_compliant = str(round(np.mean(compliant_v),2))
    mean_CB[1] = np.mean(compliant_v)
    sd_CB[1] = np.std(compliant_v)
else:
    mode_compliant = np.nan
    sd_compliant = str(np.nan)
    mean_compliant = str(np.nan)
if len(unruly_v) != 0:
    mode_unruly = stats.mode(unruly_v)[0][0]
    sd_unruly = str(round(np.std(unruly_v),2))
    mean_unruly = str(round(np.mean(unruly_v),2))
    mean_UB[1] = np.mean(unruly_v)
    sd_UB[1] = np.std(unruly_v)
else:
    mode_unruly = np.nan
    sd_unruly = str(np.nan)
    mean_unruly = str(np.nan)

criminal_opps = Criminal_opps(ḡ, σ, agents, run_length)
v, a, g, q = 0, 0, 0, 0
v, a, g, q = Simulation(criminal_opps,chosen_r[2],F,Z)
v_41 = v
state = []
compliant_v = []
unruly_v = []
tm = np.zeros((2,2))
for violation in v:
    if violation < compliant_bin:
        state.append(0)
        compliant_v.append(violation)
    elif violation >= compliant_bin:
        state.append(1)
        unruly_v.append(violation)
                
for i in range(len(state)-1):
    tm[state[i]][state[i+1]] = tm[state[i]][state[i+1]] + 1
    
prob_c = len(compliant_v)/len(state)
prob_u = len(unruly_v)/len(state)
frac_c[2] = prob_c
frac_u[2] = prob_u
prob_cc = tm[0][0]/np.sum(tm[0])
prob_cu = tm[0][1]/np.sum(tm[0])
prob_uc = tm[1][0]/np.sum(tm[1])
prob_uu = tm[1][1]/np.sum(tm[1])
if math.isnan(prob_cc):
    length_compliant = str(1)
elif prob_cc == 1:
    length_compliant = 'infinity'
else:
    length_compliant = str(math.floor(1/(1-prob_cc)))
    log_ED_compliant.append(np.log(math.floor(1/(1-prob_cc))))
if math.isnan(prob_uu):
    length_unruly = str(1)
elif prob_uu == 1:
    length_unruly = 'infinity'
else:
    length_unruly = str(math.floor(1/(1-prob_uu)))
    log_ED_unruly.append(np.log(math.floor(1/(1-prob_uu))))
if len(compliant_v) != 0:
    mode_compliant = stats.mode(compliant_v)[0][0]
    sd_compliant = str(round(np.std(compliant_v),2))
    mean_compliant = str(round(np.mean(compliant_v),2))
    mean_CB[2] = np.mean(compliant_v)
    sd_CB[2] = np.std(compliant_v)
else:
    mode_compliant = np.nan
    sd_compliant = str(np.nan)
    mean_compliant = str(np.nan)
if len(unruly_v) != 0:
    mode_unruly = stats.mode(unruly_v)[0][0]
    sd_unruly = str(round(np.std(unruly_v),2))
    mean_unruly = str(round(np.mean(unruly_v),2))
    mean_UB[2] = np.mean(unruly_v)
    sd_UB[2] = np.std(unruly_v)
else:
    mode_unruly = np.nan
    sd_unruly = str(np.nan)
    mean_unruly = str(np.nan)

criminal_opps = Criminal_opps(ḡ, σ, agents, run_length)
v, a, g, q = 0, 0, 0, 0
v, a, g, q = Simulation(criminal_opps,chosen_r[3],F,Z)
v_42 = v
state = []
compliant_v = []
unruly_v = []
tm = np.zeros((2,2))
for violation in v:
    if violation < compliant_bin:
        state.append(0)
        compliant_v.append(violation)
    elif violation >= compliant_bin:
        state.append(1)
        unruly_v.append(violation)
                
for i in range(len(state)-1):
    tm[state[i]][state[i+1]] = tm[state[i]][state[i+1]] + 1
    
prob_c = len(compliant_v)/len(state)
prob_u = len(unruly_v)/len(state)
frac_c[3] = prob_c
frac_u[3] = prob_u
prob_cc = tm[0][0]/np.sum(tm[0])
prob_cu = tm[0][1]/np.sum(tm[0])
prob_uc = tm[1][0]/np.sum(tm[1])
prob_uu = tm[1][1]/np.sum(tm[1])
if math.isnan(prob_cc):
    length_compliant = str(1)
elif prob_cc == 1:
    length_compliant = 'infinity'
else:
    length_compliant = str(math.floor(1/(1-prob_cc)))
    log_ED_compliant.append(np.log(math.floor(1/(1-prob_cc))))
if math.isnan(prob_uu):
    length_unruly = str(1)
elif prob_uu == 1:
    length_unruly = 'infinity'
else:
    length_unruly = str(math.floor(1/(1-prob_uu)))
    log_ED_unruly.append(np.log(math.floor(1/(1-prob_uu))))
if len(compliant_v) != 0:
    mode_compliant = stats.mode(compliant_v)[0][0]
    sd_compliant = str(round(np.std(compliant_v),2))
    mean_compliant = str(round(np.mean(compliant_v),2))
    mean_CB[3] = np.mean(compliant_v)
    sd_CB[3] = np.std(compliant_v)
else:
    mode_compliant = np.nan
    sd_compliant = str(np.nan)
    mean_compliant = str(np.nan)
if len(unruly_v) != 0:
    mode_unruly = stats.mode(unruly_v)[0][0]
    sd_unruly = str(round(np.std(unruly_v),2))
    mean_unruly = str(round(np.mean(unruly_v),2))
    mean_UB[3] = np.mean(unruly_v)
    sd_UB[3] = np.std(unruly_v)
else:
    mode_unruly = np.nan
    sd_unruly = str(np.nan)
    mean_unruly = str(np.nan)

criminal_opps = Criminal_opps(ḡ, σ, agents, run_length)
v, a, g, q = 0, 0, 0, 0
v, a, g, q = Simulation(criminal_opps,chosen_r[4],F,Z)
v_43 = v
state = []
compliant_v = []
unruly_v = []
tm = np.zeros((2,2))
for violation in v:
    if violation < compliant_bin:
        state.append(0)
        compliant_v.append(violation)
    elif violation >= compliant_bin:
        state.append(1)
        unruly_v.append(violation)
                
for i in range(len(state)-1):
    tm[state[i]][state[i+1]] = tm[state[i]][state[i+1]] + 1
    
prob_c = len(compliant_v)/len(state)
prob_u = len(unruly_v)/len(state)
frac_c[4] = prob_c
frac_u[4] = prob_u
prob_cc = tm[0][0]/np.sum(tm[0])
prob_cu = tm[0][1]/np.sum(tm[0])
prob_uc = tm[1][0]/np.sum(tm[1])
prob_uu = tm[1][1]/np.sum(tm[1])
if math.isnan(prob_cc):
    length_compliant = str(1)
elif prob_cc == 1:
    length_compliant = 'infinity'
else:
    length_compliant = str(math.floor(1/(1-prob_cc)))
    log_ED_compliant.append(np.log(math.floor(1/(1-prob_cc))))
if math.isnan(prob_uu):
    length_unruly = str(1)
elif prob_uu == 1:
    length_unruly = 'infinity'
else:
    length_unruly = str(math.floor(1/(1-prob_uu)))
    log_ED_unruly.append(np.log(math.floor(1/(1-prob_uu))))
if len(compliant_v) != 0:
    mode_compliant = stats.mode(compliant_v)[0][0]
    sd_compliant = str(round(np.std(compliant_v),2))
    mean_compliant = str(round(np.mean(compliant_v),2))
    mean_CB[4] = np.mean(compliant_v)
    sd_CB[4] = np.std(compliant_v)
else:
    mode_compliant = np.nan
    sd_compliant = str(np.nan)
    mean_compliant = str(np.nan)
if len(unruly_v) != 0:
    mode_unruly = stats.mode(unruly_v)[0][0]
    sd_unruly = str(round(np.std(unruly_v),2))
    mean_unruly = str(round(np.mean(unruly_v),2))
    mean_UB[4] = np.mean(unruly_v)
    sd_UB[4] = np.std(unruly_v)
else:
    mode_unruly = np.nan
    sd_unruly = str(np.nan)
    mean_unruly = str(np.nan)

# %% [markdown]
# ### Visualization

# %%
fig = plt.figure(figsize=(10,6),tight_layout=True,dpi=150)
labels = ['39','40','41','42','43']
x = range(0,5)

gs = fig.add_gridspec(2, 5)
ax1 = fig.add_subplot(gs[0,0:5])
ax2 = fig.add_subplot(gs[1,0:5])

ax1.set_title('Panel 1: Persistence of the q-attractors', fontsize='medium')
ax1.set_xticks(np.arange(0,5,1))
ax1.set_xlim([0,4])
ax1.set_xticklabels(labels)
ax1.plot(x, log_ED_compliant, color='k', linestyle='dashed',linewidth=0.5, marker='s', markersize=5, 
         label='Log of persistence in GB, $log_{10}(ED_{GB})$')
ax1.plot(x, log_ED_unruly, color='k', linestyle='dashed',linewidth=0.5, marker='o', markersize=5,
         label='Log of persistence in BB, $log_{10}(ED_{BB})$')
ax1.legend(loc='best', fontsize=10, frameon=False)

ax2.set_title('Panel 2: Time spent at the q-attractors', fontsize='medium')
ax2.set_xlabel('Deterrent Resources, $R=(39,40,41,42,43)$')
ax2.set_xticks(np.arange(0,5,1))
ax2.set_xlim([0,4])
ax2.set_xticklabels(labels)
ax2.plot(x, frac_c, color='k', linestyle='dashed',linewidth=0.5, marker='s', markersize=5,
         label='Fraction of ticks spent in GB')
ax2.plot(x, frac_u, color='k', linestyle='dashed',linewidth=0.5, marker='o', markersize=5,
         label='Fraction of ticks spent in BB')
ax2.legend(loc='best', fontsize=10, frameon=False)

#plt.savefig(path+);

# %% [markdown]
# ## Figure 3.4: The dynamics of antisocial behavior for R = 39. [2x1 panels with inset]

# %%
run_length = 10000000
agents = 100
r,z = 39, 2
ḡ, σ = 0.6, 0.20

criminal_opps = Criminal_opps(ḡ, σ, agents, run_length)
v, a, g, q = 0, 0, 0, 0
v, a, g, q = Simulation(criminal_opps,r,F,z)

q = [i*100 for i in q]
q = np.round(q, 0)
q = [int(i) for i in q]
violations = np.zeros((agents+1,agents+1))
beliefs = np.zeros((agents+1,agents+1))

for i in range(len(v)-(100+z)):
    violations[v[i]][v[i+1]] = violations[v[i]][v[i+1]] + 1
    beliefs[q[i]][q[i+1]] = beliefs[q[i]][q[i+1]] + 1

for i in range(len(violations)):
    violations[i] = violations[i]/np.sum(violations[i])

for i in range(len(beliefs)):
    if np.sum(beliefs[i]) != 0:
        beliefs[i] = beliefs[i]/np.sum(beliefs[i])
    elif np.sum(beliefs[i]) == 0:
        beliefs[i] = beliefs[i]
    
v_range = np.arange(0,agents+1)
b_range = np.arange(0,101,1)
ex_v = np.zeros(len(violations))
ex_b = np.zeros(len(beliefs))

for i in range(len(violations)):
    ex_v[i] = np.sum(v_range*(violations[i]))
    
for i in range(len(beliefs)):
    ex_b[i] = np.sum(b_range*beliefs[i])
    
Δv = ex_v - v_range
baseline = np.arange(0, agents+1)

b1 = np.empty(agents+1)
b2 = np.empty(agents+1)
b3 = np.empty(agents+1)
b4 = np.empty(agents+1)
baseline = np.arange(0, agents+1)
x = np.zeros(agents+1)
Δv = ex_v - v_range

# plot preperation (dynamics along bottom axis)
i = np.where(np.diff(np.sign(x-Δv)))[0]
b5 = np.zeros(agents+1)
b1[0:i[0]+1] = 0
b1[i[0]+1:] = np.nan
b2[i[0]:i[1]+1] = 0
b2[:i[0]] = np.nan
b2[i[1]+1:] = np.nan
b3[i[1]+2:i[2]+1] = 0
b3[:i[1]+2] = np.nan
b3[i[2]+1:] = np.nan
b4[i[2]:] = 0
b4[:i[2]] = np.nan

# %% [markdown]
# ### Visualization

# %%
# plot results
prob_eq = np.load(path+'fig31_prob_eq.npy')
agents = len(prob_eq)-1
x = np.arange(0,agents+1)
x1 = np.arange(0,30)
x2 = np.arange(70,agents+1)
x3 = np.arange(30,71)

fig = plt.figure(figsize=(12,8),tight_layout=True,dpi=150)
gs = fig.add_gridspec(4, 1)
ax1 = fig.add_subplot(gs[:3, 0])
ax2 = fig.add_subplot(gs[3, 0])

left, bottom, width, height = [0.12, 0.65, 0.25, 0.25]
left1, bottom1, width1, height1 = [0.62, 0.45, 0.2, 0.2]
my_color="k"

ax1.set_title('Panel 1: Expected violations given current violations, R=39', fontsize= 'small')
ax1.set_ylabel('Expected violations in next period ($v^{t+1})$', fontsize= 'small')
ax1.set_xlabel('Violations in the current period', fontsize= 'small')
ax1.set_xlim([0,100])
ax1.set_ylim([-5,100])
ax1.plot(baseline, color='k', linewidth=1)
ax1.plot(b1, color='k', marker=5, markerfacecolor='none', markevery=3, markersize=7)
ax1.plot(b2, color='k', marker=4, markerfacecolor='none', markevery=3, markersize=7)
ax1.plot(b3, color='k', marker=5, markerfacecolor='none', markevery=3, markersize=7)
ax1.plot(b4, color='k', marker=4, markerfacecolor='none', markevery=3, markersize=7)
ax1.plot(b5, color='k')
ax1.plot(ex_v, color='k', linestyle='dashed', linewidth=1, label='$E(v^{t+1}|v^t$)')
ax1.vlines(x=i[0], ymin=0, ymax=i[0], color='k', linestyle='dashed', linewidth=0.55)
ax1.vlines(x=i[2]+1, ymin=0, ymax=i[2]+1, color='k', linestyle='dashed', linewidth=0.55)
ax1.vlines(x=i[1]+1, ymin=0, ymax=i[1]+1, color='k', linestyle='dashed', linewidth=0.55)
ax1.annotate('Basin of attraction to $v^t$='+str(i[0]), fontsize=10, xy=(30,5))
ax1.annotate('Basin of attraction to $v^t$='+str(i[2]), fontsize=10, xy=(65,5))
ax1.annotate('$v^t$='+str(i[0]), fontsize=10, xy=(i[0]-2,-4))
ax1.annotate('$v^t$='+str(i[1]), fontsize=10, xy=(i[1]-2,-4))
ax1.annotate('$v^t$='+str(i[2]), fontsize=10, xy=(i[2]-2,-4))
ax1.legend(loc='upper center', frameon=False, fontsize=11)
ax3 = fig.add_axes([left, bottom, width, height])
sm.graphics.tsa.plot_acf(v, lags=10, unbiased=True, ax=ax3)
ax3.set_title('Autocorrelation in violations', fontsize= 'small')
ax3.set_xlabel('Lag', fontsize= 'small')
for item in ax3.collections:
    #change the color of the CI 
    if type(item)==PolyCollection:
        item.set_facecolor(my_color)
    #change the color of the vertical lines
    if type(item)==LineCollection:
        item.set_color(my_color)    
#change the color of the markers/horizontal line
for item in ax3.lines:
    item.set_color(my_color)

ax2.set_title('Panel 2: Probability of an equilibrium with $v$ violations, $R=39$', fontsize= 'small')
ax2.set_xlabel('Number of violations (v)', fontsize= 'small')
ax2.yaxis.label.set_size(11)
ax2.set_xticks(np.arange(0,agents+10,10))
ax2.set_yticks(np.arange(0, 0.25,.05))
ax2.set_xlim([0, agents])
ax2.set_ylim([0, 0.20])
ax2.plot(x, prob_eq[39], color='k', linestyle='solid',linewidth=0.5)
ax2.fill_between(x1, prob_eq[39,:30], color='lightgray', alpha=0.2)
ax2.fill_between(x3, prob_eq[39,30:71], color='dimgray', alpha=0.4)
ax2.fill_between(x2, prob_eq[39,70:], color='gray', alpha=0.8)
ax2.annotate('Probability of bad equilibrium ($v \geq 70$)', xy=(90, .10), xytext=(72, .17), fontsize=11,
            arrowprops={'arrowstyle':'->'})
ax2.annotate('Probability of good equilibrium ($v \leq 30$)', xy=(15, .11), xytext=(0, .17), fontsize=11,
            arrowprops={'arrowstyle':'->'})
ax2.annotate('Probability of other equilibrium ($30 < v < 70$)', xy=(55, .01), xytext=(40, .10), fontsize=11,
            arrowprops={'arrowstyle':'->'})

#plt.savefig(path+);

# %% [markdown]
# ## Figure 3.5: E(v|R) for baseline parameterization, the “Cliff of Positive Feedback.” [2x1 panels]

# %%
"""
        Visualizing the cliff
            Note: 
"""
agents, Z = 100, 2
R_low, R_high = 0, agents+1

v_μ = np.zeros(R_high-R_low)
g_μ = np.zeros(R_high-R_low)
a_μ = np.zeros(R_high-R_low)
v_σ = np.zeros(R_high-R_low)
v_m = np.zeros(R_high-R_low)
ϕ = np.zeros(R_high-R_low)

for r in range(R_low,R_high):
    converged, passed = False, 0
    DD1 = np.zeros(agents+1)
    DD2 = np.zeros(agents+1)
    criminal_opps = Criminal_opps(ḡ,σ,agents,block)
    v_t, a_t, g_t = Simulation(criminal_opps,r,F,Z)
    v, a, g = 0, 0, 0
    v = np.append(v, v_t)
    a = np.append(a, a_t)
    g = np.append(g, g_t)
    for i in v:
        DD1[i] = DD1[i] + 1
    while not converged:
        criminal_opps = Criminal_opps(ḡ,σ,agents,block)
        v_t, a_t, g_t = Simulation(criminal_opps,r,F,Z)
        v = np.append(v, v_t)
        a = np.append(a, a_t)
        g = np.append(g, g_t)
        for i in v:
            DD2[i] = DD2[i] + 1    
        if np.abs(np.sum((DD2/np.sum(DD2)) - (DD1/np.sum(DD1)))) < C:
            passed = passed + 1
            if passed > checks:
                converged = True
        DD1 = DD2
    DD1 = DD1/np.sum(DD1)
    v_μ[r] = np.mean(v)
    a_μ[r] = np.mean(a)
    g_μ[r] = np.mean(g)
    v_σ[r] = np.std(v)
    v_m[r] = stats.mode(v,axis=None)[0][0]
    gp = -1
    eqn = 0
    while eqn < v_μ[r]:
        gp = gp + 0.0001
        eqn= agents*norm.cdf(gp,ḡ,σ)
    ϕ[r] = norm.pdf(gp,ḡ,σ)
    
np.save(path+'fig52_mean_v.npy', v_μ)   
np.save(path+'fig52_mean_a.npy', a_μ)   
np.save(path+'fig52_mean_g.npy', g_μ)
np.save(path+'fig52_std_v.npy', v_σ)
np.save(path+'fig52_mode_v.npy', v_m)
np.save(path+'fig52_pivot_g.npy', ϕ)

# %% [markdown]
# ### Visualization

# %%
v_μ = np.load(path+'fig52_mean_v.npy')   
v_m = np.load(path+'fig52_mode_v.npy')
ex_eq_v = np.load(path+'fig31_ex_eq_v.npy')
Δ = v_μ - v_m
x = np.arange(R_low,len(v_μ))

fig = plt.figure(figsize=(10,6),tight_layout=True,dpi=150)
gs = fig.add_gridspec(3, 1)
ax1 = fig.add_subplot(gs[:2, 0])
ax2 = fig.add_subplot(gs[2, 0])
plt.xlabel('Deterrent resources (R)', fontsize= 'medium')
ax1.set_title('Panel 1: Expected violations, dynamic and equilibrium models', fontsize= 'small')
ax1.set(ylabel='Number of violators')
ax1.yaxis.label.set_size(11)
ax1.set_xticks(np.arange(0,R_high,10))
ax1.set_yticks(np.arange(0, R_high+2,10))
ax1.set_xlim([R_low, R_high])
ax1.set_ylim([0, agents+2])
ax2.set_title(r'Panel 2: Difference between mean and modal violations', fontsize= 'small')
ax2.set_xticks(np.arange(0,R_high,10))
ax2.set_xlim([R_low, R_high])
ax2.yaxis.label.set_size(11)
ax1.plot(x, v_μ, color='k', linestyle='solid',linewidth=0.75, label=r'$E(v|R)$ simulated from dynamic model')
#ax1.plot(x, ex_eq_v, color='k', linestyle=':',linewidth=0.75, label='$E(v|R)$ calculated from equilbrium model')
ax2.axhline(y=0, color='grey', linestyle='solid', linewidth=0.5)
ax2.plot(x, Δ, color='k', linestyle='solid',linewidth=0.75, label='difference between mean and modal violations')
ax1.legend(loc='best', fontsize=9, frameon=False)
ax2.legend(loc='lower right', fontsize=9, frameon=False)

#plt.savefig(path+);

# %% [markdown]
# ## Figure 3.6: Robustness tests, cliff variants on z, N, σ, q, and P(v,R). [2x3 panels]

# %%
"""
    comparatives on z, N, sigma, q, and P(v,R)
"""

# benchmark
agents, Z = 100, 2
R_low, R_high = 0, agents+1
μ_v = np.zeros(R_high-R_low)

for r in range(R_low,R_high):
    converged, passed = False, 0
    DD1 = np.zeros(agents+1)
    DD2 = np.zeros(agents+1)
    criminal_opps = Criminal_opps(ḡ,σ,agents,block)
    v_t, a_t, g_t = Simulation(criminal_opps,r,F,Z)
    v, a = 0, 0
    v = np.append(v, v_t)
    a = np.append(a, a_t)
    for i in v:
        DD1[i] = DD1[i] + 1
    while not converged:
        criminal_opps = Criminal_opps(ḡ,σ,agents,block)
        v_t, a_t, g_t = Simulation(criminal_opps,r,F,Z)
        v = np.append(v, v_t)
        a = np.append(a, a_t)
        for i in v:
            DD2[i] = DD2[i] + 1    
        if np.abs(np.sum((DD2/np.sum(DD2)) - (DD1/np.sum(DD1)))) < C:
            passed = passed + 1
            if passed > checks:
                converged = True
        DD1 = DD2
    DD1 = DD1/np.sum(DD1)
    μ_v[r] = np.mean(v)
# store results for 100 agents
benchmark = μ_v

agents, Z = 50, 2
R_high = agents+1
μ_v = np.zeros(R_high-R_low)

for r in range(R_low,R_high):
    converged, passed = False, 0
    DD1 = np.zeros(agents+1)
    DD2 = np.zeros(agents+1)
    criminal_opps = Criminal_opps(ḡ,σ,agents,block)
    v_t, a_t, g_t = Simulation(criminal_opps,r,F,Z)
    v, a = 0, 0
    v = np.append(v, v_t)
    a = np.append(a, a_t)
    for i in v:
        DD1[i] = DD1[i] + 1
    while not converged:
        criminal_opps = Criminal_opps(ḡ,σ,agents,block)
        v_t, a_t, g_t = Simulation(criminal_opps,r,F,Z)
        v = np.append(v, v_t)
        a = np.append(a, a_t)
        for i in v:
            DD2[i] = DD2[i] + 1    
        if np.abs(np.sum((DD2/np.sum(DD2)) - (DD1/np.sum(DD1)))) < C:
            passed = passed + 1
            if passed > checks:
                converged = True
        DD1 = DD2
    DD1 = DD1/np.sum(DD1)
    μ_v[r] = np.mean(v)
# store results for 200 agents
E_N_200 = μ_v

"""
    comparatives on Z
"""
agents, Z = 100, 4
R_high = agents+1
μ_v = np.zeros(R_high-R_low) 

for r in range(R_low,R_high):
    converged, passed = False, 0
    DD1 = np.zeros(agents+1)
    DD2 = np.zeros(agents+1)
    criminal_opps = Criminal_opps(ḡ,σ,agents,block)
    v_t, a_t, g_t = Simulation(criminal_opps,r,F,Z)
    v, a = 0, 0
    v = np.append(v, v_t)
    a = np.append(a, a_t)
    for i in v:
        DD1[i] = DD1[i] + 1
    while not converged:
        criminal_opps = Criminal_opps(ḡ,σ,agents,block)
        v_t, a_t, g_t = Simulation(criminal_opps,r,F,Z)
        v = np.append(v, v_t)
        a = np.append(a, a_t)
        for i in v:
            DD2[i] = DD2[i] + 1    
        if np.abs(np.sum((DD2/np.sum(DD2)) - (DD1/np.sum(DD1)))) < C:
            passed = passed + 1
            if passed > checks:
                converged = True
        DD1 = DD2
    DD1 = DD1/np.sum(DD1)
    μ_v[r] = np.mean(v)
# store results and run for 50 agents   
E_Z_6 = μ_v

"""
comparatives on catch function
"""
agents, Z = 100, 2
R_high = agents+1
μ_v = np.zeros(R_high-R_low) 

for r in range(R_low,R_high):
    converged, passed = False, 0
    DD1 = np.zeros(agents+1)
    DD2 = np.zeros(agents+1)
    criminal_opps = Criminal_opps(ḡ,σ,agents,block)
    v_t, a_t, g_t = Simulation_exp(criminal_opps,r,F,Z)
    v, a, g = 0, 0, 0
    v = np.append(v, v_t)
    a = np.append(a, a_t)
    g = np.append(g, g_t)
    for i in v:
        DD1[i] = DD1[i] + 1
    while not converged:
        criminal_opps = Criminal_opps(ḡ,σ,agents,block)
        v_t, a_t, g_t = Simulation_exp(criminal_opps,r,F,Z)
        v = np.append(v, v_t)
        a = np.append(a, a_t)
        g = np.append(g, g_t)
        for i in v:
            DD2[i] = DD2[i] + 1    
        if np.abs(np.sum((DD2/np.sum(DD2)) - (DD1/np.sum(DD1)))) < C:
            passed = passed + 1
            if passed > checks:
                converged = True
        DD1 = DD2
    DD1 = DD1/np.sum(DD1)
    μ_v[r] = np.mean(v)
# store results and run for 50 agents
E_exp = μ_v


"""
comparatives on sigma
"""
agents, Z = 100, 2
R_high = agents+1
μ_v = np.zeros(R_high-R_low) 

for r in range(R_low,R_high):
    converged, passed = False, 0
    DD1 = np.zeros(agents+1)
    DD2 = np.zeros(agents+1)
    criminal_opps = Criminal_opps(ḡ,0.15,agents,block)
    v_t, a_t, g_t = Simulation(criminal_opps,r,F,Z)
    v, a, g = 0, 0, 0
    v = np.append(v, v_t)
    a = np.append(a, a_t)
    g = np.append(g, g_t)
    for i in v:
        DD1[i] = DD1[i] + 1
    while not converged:
        criminal_opps = Criminal_opps(ḡ,0.15,agents,block)
        v_t, a_t, g_t = Simulation(criminal_opps,r,F,Z)
        v = np.append(v, v_t)
        a = np.append(a, a_t)
        g = np.append(g, g_t)
        for i in v:
            DD2[i] = DD2[i] + 1    
        if np.abs(np.sum((DD2/np.sum(DD2)) - (DD1/np.sum(DD1)))) < C:
            passed = passed + 1
            if passed > checks:
                converged = True
        DD1 = DD2
    DD1 = DD1/np.sum(DD1)
    μ_v[r] = np.mean(v)
# store results
v_low_σ = μ_v

np.save(path+'fig53_benchmark.npy', benchmark)
np.save(path+'fig53_E_N_200.npy', E_N_200)
np.save(path+'fig53_E_Z_6.npy', E_Z_6)
np.save(path+'fig53_E_exp.npy', E_exp)
np.save(path+'fig53_v_low.npy', v_low_σ)

# %% [markdown]
# ### Visualization

# %%
benchmark = np.load(path+'fig53_benchmark.npy')
E_N_200 = np.load(path+'fig53_E_N_200.npy')
E_Z_6 = np.load(path+'fig53_E_Z_6.npy')
E_exp = np.load(path+'fig53_E_exp.npy')
v_low_σ = np.load(path+'fig53_v_low.npy')
v_het_q = np.load(path+'fig53_v_het_q.npy')
v_uniform = np.load(path+'fig53_v_uniform.npy')

x_200 = np.arange(0,50+1)/50
x = np.arange(R_low,R_high)

fig = plt.figure(figsize=(12,8),tight_layout=True,dpi=150)
gs = fig.add_gridspec(2, 3)
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[0, 2])
ax4 = fig.add_subplot(gs[1, 0])
ax5 = fig.add_subplot(gs[1, 1])
ax6 = fig.add_subplot(gs[1, 2])

ax1.set_title('Panel 1: Size of population', fontsize= 'medium')
ax1.set_xlabel('Deterrent resources per agent (R/N)', fontsize= 'medium')
ax1.set(ylabel='violators/N')
ax1.yaxis.label.set_size(11)
ax1.set_xticks(np.arange(0,1.1,0.1))
ax1.set_yticks(np.arange(0, 1.1,0.1))
ax1.set_xlim([0, 1])
ax1.set_ylim([0, 1])
ax1.plot(x/100, benchmark/100, color='k', linestyle='solid',linewidth=0.75,label='E(v|R) baseline')
ax1.plot(x_200, E_N_200/50, color='k', linestyle='dashed',linewidth=1, label='E(v|R), N = 50')
#ax1.legend(loc='best', fontsize=10, frameon=False)

ax2.set_title('Panel 2: Length of z-history', fontsize= 'medium')
ax2.set_xticks(np.arange(0,agents+10,10))
ax2.set_yticks(np.arange(0,agents+10,10))
ax2.set_xlim([0, agents])
ax2.set_ylim([0, agents])
ax2.set_xlabel('Deterrent resources (R)', fontsize= 'medium')
ax2.set(ylabel='violators')
ax2.yaxis.label.set_size(11)
ax2.plot(x, benchmark, color='k', linestyle='solid',linewidth=0.75, label='E(v|R) baseline')
ax2.plot(x, E_Z_6, color='k', linestyle='dashed',linewidth=1, label='E(v|R), Z = 2')
#ax2.legend(loc='best', fontsize=10, frameon=False)

ax3.set_title('Panel 3: Tighter Distribution of g', fontsize= 'medium')
ax3.set_xticks(np.arange(0,agents+10,10))
ax3.set_yticks(np.arange(0,agents+10,10))
ax3.set_xlim([0, agents])
ax3.set_ylim([0, agents])
ax3.set_xlabel('Deterrent resources (R)', fontsize= 'medium')
ax3.set(ylabel='violators')
ax3.yaxis.label.set_size(11)
ax3.plot(x, benchmark, color='k', linestyle='solid',linewidth=0.75, label='E(v|R) baseline')
ax3.plot(x, v_low_σ, color='k', linestyle='dashed',linewidth=1, label='E(v|R), σ = 0.15')
#ax4.legend(loc='best', fontsize=10, frameon=False)

ax4.set_title('Panel 4: Different apprehension technology', fontsize= 'medium')
ax4.set_xticks(np.arange(0,agents+10,10))
ax4.set_yticks(np.arange(0,agents+10,10))
ax4.set_xlim([0, agents])
ax4.set_ylim([0, agents])
ax4.set_xlabel('Deterrent resources (R)', fontsize= 'medium')
ax4.set(ylabel='violators')
ax4.yaxis.label.set_size(11)
ax4.plot(x, benchmark, color='k', linestyle='solid',linewidth=0.75, label='E(v|R) baseline')
ax4.plot(x, E_exp, color='k', linestyle='dashed',linewidth=1, label='E(v|R), exp. catch function')
#ax3.legend(loc='best', fontsize=10, frameon=False)

ax5.set_title('Panel 5: Heterogeneous q', fontsize= 'medium')
ax5.set_xticks(np.arange(0,agents+10,10))
ax5.set_yticks(np.arange(0,agents+10,10))
ax5.set_xlim([0, agents])
ax5.set_ylim([0, agents])
ax5.set_xlabel('Deterrent resources (R)', fontsize= 'medium')
ax5.set(ylabel='violators')
ax5.yaxis.label.set_size(11)
ax5.plot(x, benchmark, color='k', linestyle='solid',linewidth=0.75, label='E(v|R) baseline')
ax5.plot(x, v_het_q, color='k', linestyle='dashed',linewidth=1, label='E(v|R), σ = 0.15')
#ax4.legend(loc='best', fontsize=10, frameon=False)

ax6.set_title('Panel 6: Uniform distribution of g', fontsize= 'medium')
ax6.set_xticks(np.arange(0,agents+10,10))
ax6.set_yticks(np.arange(0,agents+10,10))
ax6.set_xlim([0, agents])
ax6.set_ylim([0, agents])
ax6.set_xlabel('Deterrent resources (R)', fontsize= 'medium')
ax6.set(ylabel='violators')
ax6.yaxis.label.set_size(11)
ax6.plot(x, benchmark, color='k', linestyle='solid',linewidth=0.75, label='E(v|R) baseline')
ax6.plot(x, v_uniform, color='k', linestyle='dashed',linewidth=1, label='E(v|R), σ = 0.15')
#ax4.legend(loc='best', fontsize=10, frameon=False)

#plt.savefig(path+);

# %% [markdown]
# ## Figure 3.7:  Expected violations for the entire passive policy space, E(v|R, F ). [1 panel]

# %%
"""
        Fig 4: Surface plot in F, R space
            Note: 
"""
agents, Z = 100, 2
F_range = np.arange(0,1.52,0.05)
R_low, R_high = 0, agents+1

v_μ = np.zeros((R_high-R_low, len(F_range)))
v_σ = np.zeros((R_high-R_low, len(F_range)))
a_μ = np.zeros((R_high-R_low, len(F_range)))
g_μ = np.zeros((R_high-R_low, len(F_range)))
SD = np.zeros(((R_high-R_low, len(F_range), agents+1)))

for r in range(R_low,R_high):
    index = 0
    for f in F_range:
        converged, passed = False, 0
        DD1 = np.zeros(agents+1)
        DD2 = np.zeros(agents+1)
        criminal_opps = Criminal_opps(ḡ,σ,agents,block)
        v_t, a_t, g_t = Simulation(criminal_opps,r,f,Z)
        v, a, g = 0, 0, 0
        v = np.append(v, v_t)
        a = np.append(a, a_t)
        g = np.append(g, g_t)
        for i in v:
            DD1[i] = DD1[i] + 1
        while not converged:
            criminal_opps = Criminal_opps(ḡ,σ,agents,block)
            v_t, a_t, g_t = Simulation(criminal_opps,r,f,Z)
            v = np.append(v, v_t)
            a = np.append(a, a_t)
            g = np.append(g, g_t)
            for i in v:
                DD2[i] = DD2[i] + 1    
            if np.abs(np.sum((DD2/np.sum(DD2)) - (DD1/np.sum(DD1)))) < C:
                passed = passed + 1
                if passed > checks:
                    converged = True
            DD1 = DD2
        DD1 = DD1/np.sum(DD1)
        SD[r,index] = DD1
        v_μ[r,index] = np.mean(v)
        a_μ[r,index] = np.mean(a)
        g_μ[r,index] = np.mean(g)
        v_σ[r,index] = np.std(v)
        index = index + 1

np.save(path+'fig54_mean_v.npy', v_μ)
np.save(path+'fig54_mean_a.npy', a_μ)
np.save(path+'fig54_mean_g.npy', g_μ)
np.save(path+'fig54_stddev_v.npy', v_σ)

# %% [markdown]
# ### Visualization

# %%
r_star = np.zeros((101,76))
violations_surface = [i[0:76] for i in v_μ]
violations_surface = np.asarray(violations_surface, dtype=np.float32)
r_star[:] = np.nan
r_star[34] = violations_surface[34]

f_1 = np.empty((len(violations_surface),len(violations_surface[0])))
f_1[:] = np.nan
f_1[:,51] = violations_surface[:,51]

y = np.arange(0,len(violations_surface),1)
x = np.arange(0,1.52,0.02)
fig, ax = plt.subplots(figsize=(16,12),subplot_kw={"projection": "3d"}, dpi=800)
X, Y = np.meshgrid(x, y)  # `plot_surface` expects `x` and `y` data to be 2D
ax.plot_wireframe(X, Y, violations_surface, rstride=1, cstride=1, alpha=1, color='gray', linewidth=0.5, linestyle='dashed', antialiased=True)
ax.plot_wireframe(X, Y, r_star, rstride=1, cstride=1, alpha=1, color='k', 
                  linewidth=1.5, linestyle='solid', antialiased=True)
ax.plot_wireframe(X, Y, f_1, rstride=1, cstride=1, alpha=1, color='k', 
                  linewidth=1.5, linestyle='solid', antialiased=True)
ax.text(0,33,102,'$E(v|R=33, F$)',color='k', fontsize='13')
ax.text(1.25,0,109,'$E(v|R, F=1$)',color='k', fontsize='13')
ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.))
ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.set_xticks(np.arange(0,1.6,0.25))
ax.set_yticks(np.arange(0, 110,10))
ax.set_zticks(np.arange(0,105,10))
ax.set_xlim([0, 1.5])
ax.set_ylim([0, 100])
ax.set_zlim([0, 100])
ax.set_ylabel('Deterrent resources, $R=\{0,...N\}$')
ax.set_xlabel('Level of fine, $F=\{0,...1.5\}$')
ax.set_zlabel('$E(v | R, F)$')
ax.view_init(20,25) 

#plt.savefig(path+)

# %% [markdown]
# ## Figure 3.8: Cost of antisocial behavior for ρ = 2 and λ = 2, 5, 400. [1x3 panels]

# %%
g_μ = np.load(path+'fig52_mean_g.npy')
R_low, R_high = 0, len(g_μ)
x = np.arange(0,len(g_μ))

ex_cost_05 = np.zeros(R_high-R_low)
ex_cost_22 = np.zeros(R_high-R_low)
ex_cost_25 = np.zeros(R_high-R_low)
ex_cost_220 = np.zeros(R_high-R_low)


for r in range(R_low,R_high):
    ex_cost_05[r] = 0*r + (5-1)*g_μ[r]
    ex_cost_22[r] = 2*r + (2-1)*g_μ[r]
    ex_cost_25[r] = 2*r + (5-1)*g_μ[r]
    ex_cost_220[r] = 2*r + (400-1)*g_μ[r]

fig = plt.figure(figsize=(16,8),tight_layout=True,dpi=150)

gs = fig.add_gridspec(1, 12)
ax1 = fig.add_subplot(gs[0, 0:4])
ax2 = fig.add_subplot(gs[0, 4:8])
ax3 = fig.add_subplot(gs[0, 8:12])
#ax4 = fig.add_subplot(gs[1, 1])

ax1.set(ylabel='E(cost|R)')
ax1.set_title('Panel 1: Low cost of ASB (spitting on the sidewalk)', fontsize='large')
ax1.set_xticks(np.arange(0,R_high,10))
ax1.set_xlim([R_low, R_high])
ax1.yaxis.label.set_size(10)
ax1.axhline(y=ex_cost_22[0], color='k',linewidth=1, linestyle='dashed')
ax1.axhline(y=ex_cost_22[100], color='k',linewidth=1, linestyle='dashed')
ax1.annotate('E(cost|R=0) = '+str(round(ex_cost_22[0])), fontsize=12, xy=(45,ex_cost_22[0]+2))
ax1.annotate('E(cost|R=N) = '+str(round(ex_cost_22[100])), fontsize=12, xy=(45,ex_cost_22[100]-5))
ax1.plot(x, ex_cost_22, color='k', linestyle='solid',linewidth=1, 
         label='ρ=2, λ=2')
ax1.legend(loc='center left', fontsize=13, frameon=False)

#ax2.set(ylabel='E(cost|R)')
ax2.set_title('Panel 2: Intermediate cost of ASB (property crime)', fontsize='large')
ax2.set_xlabel('Deterrent resources (R)', fontsize= 'medium')
ax2.set_xticks(np.arange(0,R_high,10))
ax2.set_xlim([R_low, R_high])
ax2.yaxis.label.set_size(11)
ax2.axhline(y=ex_cost_25[0], color='k',linewidth=0.5, linestyle='dashed')
ax2.axhline(y=ex_cost_25[100], color='k',linewidth=0.5, linestyle='dashed')
ax2.annotate('E(cost|R=0) = '+str(round(ex_cost_25[0])), fontsize=12, xy=(45,ex_cost_25[0]-5))
ax2.annotate('E(cost|R=N) = '+str(round(ex_cost_25[100])), fontsize=12, xy=(45,ex_cost_25[100]+2))
ax2.plot(x, ex_cost_25, color='k', linestyle='solid',linewidth=1, 
         label='ρ=2, λ=5')
ax2.legend(loc='lower right', fontsize=13, frameon=False)

#ax3.set(ylabel='E(cost|R)')
ax3.set_title('Panel 3: High cost of ASB (nuclear terrorism)', fontsize='large')
ax3.set_xticks(np.arange(0,R_high,10))
ax3.set_xlim([R_low, R_high])
ax3.yaxis.label.set_size(10)
ax3.axhline(y=ex_cost_220[0], color='k',linewidth=0.5, linestyle='dashed')
ax3.axhline(y=ex_cost_220[100], color='k',linewidth=0.5, linestyle='dashed')
ax3.annotate('E(cost|R=N) = '+str(round(ex_cost_220[100])), fontsize=12, xy=(45,ex_cost_220[100]+500))
ax3.annotate('E(cost|R=0) = '+str(round(ex_cost_220[0])), fontsize=12, xy=(45,ex_cost_220[0]-1000))
ax3.plot(x, ex_cost_220, color='k', linestyle='solid',linewidth=1, 
         label='ρ=2, λ=400')
ax3.legend(loc='center right', fontsize=13, frameon=False)

#plt.savefig(path+);

# %% [markdown]
# ### Figure 3.9: Useful indices related to the cost of ASB [2x1 Panels]

# %%
v_μ = np.load(path+'fig52_mean_v.npy')
a_μ = np.load(path+'fig52_mean_a.npy')
R_low, R_high = 0, len(v_μ)
x = np.arange(0,len(v_μ))
agents = 100

ex_cap = np.zeros(R_high-R_low)
deterred = np.zeros(R_high-R_low)
compliance = np.zeros(R_high-R_low)
investigation_rate = np.zeros(R_high-R_low)
apprehension_rate = np.zeros(R_high-R_low)
x = np.arange(R_low,R_high)

for r in range(R_low,R_high):
    ex_cap[r] = max((r-v_μ[r])/r,0)
    investigation_rate[r] = min((v_μ[r]/v_μ[r]),r/v_μ[r])
    apprehension_rate[r] = a_μ[r]/v_μ[r]
    deterred[r] = a_μ[r]
    compliance[r] = agents-v_μ[r]

fig = plt.figure(figsize=(10,6),tight_layout=True,dpi=150)

gs = fig.add_gridspec(2, 1)
ax1 = fig.add_subplot(gs[:1, 0])
ax2 = fig.add_subplot(gs[1, 0])

plt.xlabel('Deterrent resources (R)', fontsize= 'medium')
ax1.set_title('Panel 1: Observables, investigations and apprehensions', fontsize= 'medium')
ax1.yaxis.label.set_size(11)
ax1.set_xticks(np.arange(0,R_high,10))
ax1.set_yticks(np.arange(0, (agents/agents)+0.1,0.2))
ax1.set_xlim([R_low, R_high])
ax1.set_ylim([-0.1, (agents/agents)+0.1])
ax2.set_xticks(np.arange(0,R_high,10))
ax2.set_xlim([R_low, R_high])
#ax2.set(ylabel='apprehended/compliers')
ax2.yaxis.label.set_size(11)
ax1.plot(x, investigation_rate, color='k', linestyle='solid',linewidth=0.75, label='Investigation rate')
ax1.plot(x, apprehension_rate, color='k', linestyle='dotted',linewidth=0.75, label='Apprehension rate')

ax2.set_title('Panel 2: Compliance and reserve capacity', fontsize= 'medium')
ax2.plot(x, compliance/agents, color='k', linestyle='solid',linewidth=0.75, label='Compliance')
ax2.plot(x, ex_cap, color='k', linestyle='dotted',linewidth=0.75, label='Reserve capacity rate')
ax1.legend(loc='best', fontsize=10, frameon=False)
ax2.legend(loc='best', fontsize=10, frameon=False)

#plt.savefig(path+);

# %% [markdown]
# ## Figure 4.1: Illustrating the mechanics of a crackdown policy. [3x1]

# %%
"""
    Produces a sample time series
        Note: User has to select time slice for visulization
        
"""
# parameters
OCD = [37,59,50]
block = 1000
agents, F, Z = 100, 1, 2
α,β = 1, 0.25

criminal_opps = Criminal_opps(ḡ,σ,agents,block)
v, a, g, q, p, r = Crackdown_q(criminal_opps, OCD[2], OCD[0], OCD[1], F, Z)

# %% [markdown]
# ### Visualization

# %%
fig = plt.figure(figsize=(16,12),dpi=150)
gs = fig.add_gridspec(3, 1)
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[1, 0])
ax3 = fig.add_subplot(gs[2, 0])

ax1.set_title('Panel 1: Illustrative time path of violations and apprehenshion rate')
ax1.set(ylabel='Violations')
ax1i = ax1.twinx()
ax1.set_xticks(np.arange(0,110, 10))
ax1.set_yticks(np.arange(0,agents, 10))
ax1.set_xlim([0, 100])
ax1.set_ylim([0, agents])
ax1.plot(v[700:800], color='k', linestyle='solid',linewidth=0.75)
ax1i.plot(a[700:800]/v[700:800], color ='k', linestyle='dashed',linewidth=0.75)
ax1.hlines(50, xmin=0, xmax=100, linestyle='dashed',linewidth=0.75) 
ax1.vlines(40, ymin=0, ymax=agents, linestyle='dashed',linewidth=0.75) 
ax1.vlines(47, ymin=0, ymax=agents, linestyle='dashed',linewidth=0.75)
ax1.axhspan(0, 50, alpha=0.10, color='silver')
ax1.axvspan(40, 47, alpha=0.25, color='silver')
ax1.text(15,35,'Violations',color='k',fontsize='12')
ax1.text(5,60,'Apprehension rate',color='k',fontsize='12')
ax1.text(50,36,'Good Bin (GB)',color='k',fontsize='12')
ax1i.set(ylabel='Apprehension rate ($a/v$)')
ax1i.set_xticks(np.arange(0,110, 10))
ax1i.set_yticks(np.arange(0, 1, 0.1))
ax1i.set_xlim([0, 100])
ax1i.set_ylim([0, 1])


ax2.set_title('Panel 2: Illustrative time path of deterrence spending ($R_t$)')
ax2.set(ylabel='Deterrent resource ($R$)')
ax2.set_xticks(np.arange(0,110, 10))
ax2.set_yticks(np.arange(0,agents, 10))
ax2.set_xlim([0, 100])
ax2.set_ylim([0, agents])
ax2.plot(r[700:800], color ='k', linestyle='solid',linewidth=0.75, 
            label = 'R history')
ax2.vlines(40, ymin=0, ymax=agents, linestyle='dashed',linewidth=0.75) 
ax2.vlines(47, ymin=0, ymax=agents, linestyle='dashed',linewidth=0.75)
ax2.axvspan(40, 47, alpha=0.25, color='silver')
ax2.annotate('Crackdown implemented', xy=(41, 38), xytext=(10, 70), fontsize=13,
            arrowprops=dict(facecolor='black', shrink=0.0005, width=0.15))
ax2.annotate('$R=37$ while $v_t$ in good bin', xy=(60, 38), xytext=(70, 70), fontsize=13,
            arrowprops=dict(facecolor='black', shrink=0.0005, width=0.15))

ax3.set_title('Panel 3: Illustrative time path of $p_t$ and $q_t$')
ax3.set(ylabel='Number of violators')
ax3.set(xlabel='Ticks (T)')
ax3.set_xticks(np.arange(0,110, 10))
ax3.set_yticks(np.arange(0,1.1, 0.1))
ax3.set_xlim([0, 100])
ax3.set_ylim([0, 1])
ax3.plot(p[700:800], color='k', linestyle='solid',linewidth=0.75, label='Objective probability of apprehension ($p_t$)')
ax3.plot(q[700:800], color='k', linestyle='dashed',linewidth=0.75, label='Subjective probability of apprehension ($q_t$)')
ax3.vlines(40, ymin=0, ymax=agents, linestyle='dashed',linewidth=0.75) 
ax3.vlines(47, ymin=0, ymax=agents, linestyle='dashed',linewidth=0.75)
ax3.axvspan(40, 47, alpha=0.25, color='silver')
ax3.annotate('Crackdown resets $q$', xy=(46, 0.75), xytext=(55, 0.4), fontsize=13,
            arrowprops=dict(facecolor='black', shrink=0.0005, width=0.15))
ax3.legend(loc='lower right', fontsize=11, frameon=False)

#plt.savefig(path+);

# %% [markdown]
# ## Figure 4.2: Extinguishing BB with crackdown. [2x1 panels with 4 insets]

# %%
run_length = 10000000
policy = [53,39,60]
agents, F, z = 100, 1, 2
α,β = 1, 0.25
ḡ, σ = 0.6, 0.20

criminal_opps = Criminal_opps(ḡ,σ,agents,run_length)
v1, a1, g1, q1, p1, r1 = 0, 0, 0, 0, 0, 0
v1, a1, g1, q1, p1, r1 = Crackdown_q(criminal_opps, policy[0], policy[1], policy[2], F, z)

violations = np.zeros((agents+1,agents+1))

for i in range(len(v1)-(100+z)):
    violations[v1[i]][v1[i+1]] = violations[v1[i]][v1[i+1]] + 1

for i in range(len(violations)):
    violations[i] = violations[i]/np.sum(violations[i])
    
v_range = np.arange(0,agents+1)
ex_v1 = np.zeros(len(violations))

for i in range(len(violations)):
    ex_v1[i] = np.sum(v_range*(violations[i]))
    
Δv1 = ex_v1 - v_range
baseline = np.arange(0, agents+1)

c1 = np.empty(agents+1)
c2 = np.empty(agents+1)
baseline = np.arange(0, agents+1)
x = np.zeros(agents+1)
Δv1 = ex_v1 - v_range

# plot preperation (dynamics along bottom axis)
i1 = np.where(np.diff(np.sign(x-Δv1)))[0]
c1[0:i1[0]+1] = 0
c1[i1[0]+1:] = np.nan
c2[i1[0]:] = 0
c2[:i1[0]] = np.nan

# %% [markdown]
# ### Visualization

# %%
# plot preperation (dynamics along bottom axis)

i = np.where(np.diff(np.sign(x-Δv)))[0]
b5 = np.zeros(agents+1)
b1[0:i[0]+1] = 0
b1[i[0]+1:] = np.nan
b2[i[0]:i[1]+1] = 0
b2[:i[0]] = np.nan
b2[i[1]+1:] = np.nan
b3[i[1]+2:i[2]+1] = 0
b3[:i[1]+2] = np.nan
b3[i[2]+1:] = np.nan
b4[i[2]:] = 0
b4[:i[2]] = np.nan

# plot results
fig = plt.figure(figsize=(12,9),tight_layout=True,dpi=150)
gs = fig.add_gridspec(6, 1)
ax1 = fig.add_subplot(gs[:3, 0])
ax4 = fig.add_subplot(gs[3:,0])

left, bottom, width, height = [0.12, 0.72, 0.20, 0.20]
left1, bottom1, width1, height1 = [0.74, 0.64, 0.20, 0.20]

left2, bottom2, width2, height2 = [0.12, 0.22, 0.20, 0.20]
left3, bottom3, width3, height3 = [0.75, 0.14, 0.20, 0.20]
my_color="k"

ax1.set_title('Panel 1: Expected violations given current violations, ($BE=53, R_{GB}=39, R_{BB}=60$)', fontsize= 'small')
ax1.set_ylabel('Expected violations in next period ($v^{t+1})$', fontsize= 'small')
ax1.set_xlabel('Violations in the current period', fontsize= 'small')
ax1.set_xlim([0,100]) 
ax1.set_ylim([-5,100])
ax1.plot(baseline, color='k', linewidth=1)
ax1.plot(c1, color='k', marker=5, markerfacecolor='none', markevery=3, markersize=7)
ax1.plot(c2, color='k', marker=4, markerfacecolor='none', markevery=3, markersize=7)
ax1.plot(ex_v1, color='k', linestyle='dashed', linewidth=1, label='$E(v^{t+1}|v^t$)')
ax1.vlines(x=i1[0], ymin=0, ymax=i1[0], color='k', linestyle='dashed', linewidth=0.55)
#ax1.annotate('Basin of attraction to $v_t$='+str(i[0]), fontsize=10, xy=(30,5))
ax1.annotate('$v^t$='+str(i[0]), fontsize=10, xy=(i1[0]-2,-4))
ax1.legend(loc='upper center', frameon=False, fontsize=11)

ax2 = fig.add_axes([left, bottom, width, height])
sm.graphics.tsa.plot_acf(v1, lags=10, unbiased=True, ax=ax2)
ax2.set_title('Autocorrelation in violations', fontsize= 'small')
ax2.set_xlabel('Lag', fontsize= 'small')
for item in ax2.collections: 
    if type(item)==PolyCollection:
        item.set_facecolor(my_color)
    if type(item)==LineCollection:
        item.set_color(my_color)    
for item in ax2.lines:
    item.set_color(my_color)

ax3 = fig.add_axes([left1, bottom1, width1, height1])
ax3.set_xlim([0,100]) 
ax3.axvline(policy[0], linestyle='dashed', color='k')
ax3.axvspan(policy[0], agents, alpha=0.25, color='silver')
#ax3.annotate('BB', xy=(70,0.015), fontsize=11)
ax3.hist(v1,color='gray', orientation ='vertical', density=True, lw=0, bins=25)
ax3.set_title('Frequency distribution of violations', fontsize= 'small')
ax3.set_xlabel('$v$', fontsize= 'small')


    
ax4.set_title('Panel 2: Expected violations given current violations, R=39', fontsize= 'small')
ax4.set_ylabel('Expected violations in next period ($v^{t+1})$', fontsize= 'small')
ax4.set_xlabel('Violations in the current period', fontsize= 'small')
ax4.set_xlim([0,100])
ax4.set_ylim([-5,100])
ax4.plot(baseline, color='k', linewidth=1)
ax4.plot(b1, color='k', marker=5, markerfacecolor='none', markevery=3, markersize=7)
ax4.plot(b2, color='k', marker=4, markerfacecolor='none', markevery=3, markersize=7)
ax4.plot(b3, color='k', marker=5, markerfacecolor='none', markevery=3, markersize=7)
ax4.plot(b4, color='k', marker=4, markerfacecolor='none', markevery=3, markersize=7)
ax4.plot(b5, color='k')
ax4.plot(ex_v, color='k', linestyle='dashed', linewidth=1, label='$E(v^{t+1}|v^t$)')
ax4.vlines(x=i[0], ymin=0, ymax=i1[0], color='k', linestyle='dashed', linewidth=0.55)
ax4.vlines(x=i[2]+1, ymin=0, ymax=i[2]+1, color='k', linestyle='dashed', linewidth=0.55)
ax4.vlines(x=i[1]+1, ymin=0, ymax=i[1]+1, color='k', linestyle='dashed', linewidth=0.55)
ax4.annotate('Basin of attraction to $v^t$='+str(i[0]), fontsize=10, xy=(30,5))
ax4.annotate('Basin of attraction to $v^t$='+str(i[2]), fontsize=10, xy=(65,5))
ax4.annotate('$v^t$='+str(i[0]), fontsize=10, xy=(i[0]-2,-4))
ax4.annotate('$v^t$='+str(i[1]), fontsize=10, xy=(i[1]-2,-4))
ax4.annotate('$v^t$='+str(i[2]), fontsize=10, xy=(i[2]-2,-4))

ax5 = fig.add_axes([left2, bottom2, width2, height2])
sm.graphics.tsa.plot_acf(v, lags=10, unbiased=True, ax=ax5)
ax5.set_title('Autocorrelation in violations', fontsize= 'small')
ax5.set_xlabel('Lag', fontsize= 'small')
for item in ax5.collections:
    if type(item)==PolyCollection:
        item.set_facecolor(my_color)
    if type(item)==LineCollection:
        item.set_color(my_color)    
for item in ax5.lines:
    item.set_color(my_color)

ax6 = fig.add_axes([left3, bottom3, width3, height3])
ax6.set_xlim([0,100]) 
ax6.axvline(50, linestyle='dashed', color='k')
ax6.axvspan(50, agents, alpha=0.25, color='silver')
#ax4.annotate('BB', xy=(70,0.015), fontsize=11)
ax6.hist(v,color='gray', orientation ='vertical', density=True, lw=0, bins=25)
ax6.set_title('Frequency distribution of violations', fontsize= 'small')
ax6.set_xlabel('$v$', fontsize= 'small')
ax6.legend(loc='upper center', frameon=False, fontsize=11)

#plt.savefig(path+);
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Figure 4.3: Surface plots of costs in BE, RBB, and RGB space. [1x3 panels]

# %%
block, checks = 20000, 5
OCD = [30,57,35]
BE = np.arange(0,71)
RGB = np.arange(0,71)
RBB = np.arange(0,71)

ex_g = np.zeros((len(BE),len(RBB)))
ex_r = np.zeros((len(BE),len(RBB)))
expected_cost = np.zeros((len(BE),len(RBB)))

for be in BE:
    for rbb in RBB:
        converged, passed = False, 0
        DD1 = np.zeros(agents+1)
        DD2 = np.zeros(agents+1)
        criminal_opps = Criminal_opps(ḡ,σ,agents,block)
        v_t, a_t, g_t, r_t = Crackdown(criminal_opps,be, OCD[0], rbb,F,Z)
        v, a, g, r = 0, 0, 0, 0
        v = np.append(v, v_t)
        a = np.append(a, a_t)
        g = np.append(g, g_t)
        r = np.append(r, r_t)
        for i in v:
            DD1[i] = DD1[i] + 1
        while not converged:
            criminal_opps = Criminal_opps(ḡ,σ,agents,block)
            v_t, a_t, g_t, r_t = Crackdown(criminal_opps,be, OCD[0],rbb,F,Z)
            v = np.append(v, v_t)
            a = np.append(a, a_t)
            g = np.append(g, g_t)
            r = np.append(r, r_t)
            for i in v:
                DD2[i] = DD2[i] + 1    
            if np.abs(np.sum((DD2/np.sum(DD2)) - (DD1/np.sum(DD1)))) < C:
                passed = passed + 1
                if passed > checks:
                    converged = True
            DD1 = DD2
        DD1 = DD1/np.sum(DD1)
        ex_g[be,rbb] = np.mean(g)
        ex_r[be,rbb] = np.mean(r)
        expected_cost[be,rbb] = ρ*ex_r[be,rbb] + (λ-1)*ex_g[be,rbb]
        
np.save(path+'fig62_panel1.npy', expected_cost)

# %% [markdown]
# ### Visualization

# %%
cost_surface_1 = np.load(path+"fig62_panel1.npy")
cost_surface_2 = np.load(path+"fig62_panel2.npy")
cost_surface_3 = np.load(path+"fig62_panel3.npy")  

RBB = np.empty((len(cost_surface_1),len(cost_surface_1[0])))
RBB[:] = np.nan
RBB[:,OCD[1]] = cost_surface_1[:,OCD[1]]
BE1 = np.empty((len(cost_surface_1),len(cost_surface_1[0])))
BE1[:] = np.nan
BE1[OCD[2],:] = cost_surface_1[OCD[2],:]

RGB = np.empty((len(cost_surface_2),len(cost_surface_2[0])))
RGB[:] = np.nan
RGB[:,OCD[0]] = cost_surface_2[:,OCD[0]]
BE2 = np.empty((len(cost_surface_2),len(cost_surface_2[0])))
BE2[:] = np.nan
BE2[OCD[2],:] = cost_surface_2[OCD[2],:]

RBB1 = np.empty((len(cost_surface_3),len(cost_surface_3[0])))
RBB1[:] = np.nan
RBB1[OCD[1],:] = cost_surface_3[OCD[1],:]
RGB1 = np.empty((len(cost_surface_3),len(cost_surface_3[0])))
RGB1[:] = np.nan
RGB1[:,OCD[0]] = cost_surface_3[:,OCD[0]]

RGB_equals_RBB = np.empty(len(cost_surface_3))
RGB_equals_RBB[:] = np.nan

for i in range(len(cost_surface_3)):
    RGB_equals_RBB[i] = cost_surface_3[i,i]
    
intersection = np.empty((len(cost_surface_3),len(cost_surface_3[0])))
intersection[:] = np.nan
intersection[44,44:71] = cost_surface_3[44,44]
intersection[44:71,44] = cost_surface_3[44,44]

y = range(len(cost_surface_1))
x = range(len(cost_surface_1[0]))
X, Y = np.meshgrid(x, y)
xline = range(0,len(cost_surface_3))
yline = range(0,len(cost_surface_3))

fig = plt.figure(figsize=(16,12),dpi=150)
gs = fig.add_gridspec(3, 4)
ax1 = fig.add_subplot(gs[0, :], projection='3d')
ax2 = fig.add_subplot(gs[1, :], projection='3d')
ax3 = fig.add_subplot(gs[2, :], projection='3d')

ax1.set_title('Panel 1: Cost surface for $R_{GB}=30$', fontsize='medium', loc='center')
ax1.plot_wireframe(X, Y, RBB, rstride=1, cstride=1, alpha=1, color='k', 
                  linewidth=0.85, linestyle='dashed', antialiased=True)
ax1.plot_wireframe(X, Y, BE1, rstride=1, cstride=1, alpha=1, color='k', 
                  linewidth=0.85, linestyle='dashed', antialiased=True)
ax1.plot_wireframe(X, Y, cost_surface_1, rstride=2, cstride=2, alpha=0.75, color='dimgray', 
                  linewidth=0.75, linestyle='dotted', antialiased=True)
ax1.text(0,OCD[2]-10,250,'$BE^*$ = '+str(OCD[2]),color='k',fontsize='10')
ax1.text(OCD[1],0,200,'$R_{BB}^*$ = '+str(OCD[1]),color='k',fontsize='10')
ax1.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax1.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax1.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax1.set_zlim([100, 310])
ax1.set_zticks(np.arange(100, 310, 50))
ax1.set_xlim([0, 70])
ax1.set_xticks(np.arange(0, len(cost_surface[0]), 10))
ax1.set_ylim([0, 70])
ax1.set_yticks(np.arange(0, len(cost_surface[0]), 5))
ax1.set_ylabel('\n\nBin Edge ($BE$)',fontsize='9')
ax1.set_xlabel('\nR in Bad Bin ($R_{BB}$)',fontsize='9')
ax1.yaxis._axinfo["grid"]['linewidth'] = 0.5
ax1.yaxis._axinfo["grid"]['linestyle'] = ":"
ax1.xaxis._axinfo["grid"]['linewidth'] = 0.5
ax1.xaxis._axinfo["grid"]['linestyle'] = ":"
ax1.zaxis._axinfo["grid"]['linewidth'] = 0.5
ax1.zaxis._axinfo["grid"]['linestyle'] = ":"
ax1.view_init(50,30)
ax1.set_proj_type('ortho')

ax2.set_title('Panel 2: Cost surface for $R_{BB}=57$', fontsize='medium', loc='center')
ax2.plot_wireframe(X, Y, RGB, rstride=1, cstride=1, alpha=1, color='k', 
                  linewidth=0.85, linestyle='dashed', antialiased=True)
ax2.plot_wireframe(X, Y, BE2, rstride=1, cstride=1, alpha=1, color='k', 
                  linewidth=0.85, linestyle='dashed', antialiased=True)
ax2.plot_wireframe(X, Y, cost_surface_2, rstride=2, cstride=2, alpha=0.75, color='dimgray', 
                  linewidth=0.75, linestyle='dotted', antialiased=True)
ax2.text(0,OCD[2],260,'$BE^*$ = '+str(OCD[2]),color='k',fontsize='10')
ax2.text(OCD[0],0,205,'$R_{GB}^*$ = '+str(OCD[0]),color='k',fontsize='10')
ax2.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax2.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax2.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax2.set_zlim([100, 310])
ax2.set_zticks(np.arange(100, 310, 50))
ax2.set_xlim([0, 70])
ax2.set_xticks(np.arange(0, len(cost_surface[0]), 10))
ax2.set_ylim([0, 70])
ax2.set_yticks(np.arange(0, len(cost_surface[0]), 5))
ax2.set_ylabel('\n\nBin Edge ($BE$)',fontsize='9')
ax2.set_xlabel('\nR in Good Bin ($G_{BB}$)',fontsize='9')
#ax2.text2D(0.1, 0.90, "Expected Costs", transform=ax.transAxes)
ax2.yaxis._axinfo["grid"]['linewidth'] = 0.5
ax2.yaxis._axinfo["grid"]['linestyle'] = ":"
ax2.xaxis._axinfo["grid"]['linewidth'] = 0.5
ax2.xaxis._axinfo["grid"]['linestyle'] = ":"
ax2.zaxis._axinfo["grid"]['linewidth'] = 0.5
ax2.zaxis._axinfo["grid"]['linestyle'] = ":"
ax2.view_init(50,30)
ax2.set_proj_type('ortho')

ax3.set_title('Panel 3: Cost surface for $BE=35$', fontsize='medium', loc='center')
ax3.plot3D(xline, yline, RGB_equals_RBB, alpha=1, color='k', 
                  linewidth=0.85, linestyle='solid', antialiased=True)
ax3.plot_wireframe(X, Y, intersection, rstride=1, cstride=1, alpha=1, color='k', 
                  linewidth=1, linestyle='dotted', antialiased=True)
ax3.plot_wireframe(X, Y, RBB1, rstride=1, cstride=1, alpha=1, color='k', 
                  linewidth=0.85, linestyle='dashed', antialiased=True)
ax3.plot_wireframe(X, Y, RGB1, rstride=1, cstride=1, alpha=1, color='k', 
                  linewidth=0.85, linestyle='dashed', antialiased=True)
ax3.plot_wireframe(X, Y, cost_surface_3, rstride=1, cstride=1, alpha=0.5, color='dimgray', 
                  linewidth=0.85, linestyle='dotted', antialiased=True)
ax3.text(0,OCD[1],275,'$R_{BB}^*$ = '+str(OCD[1]),color='k',fontsize='10')
ax3.text(OCD[0],0,280,'$R_{GB}^*$ = '+str(OCD[0]),color='k',fontsize='10')
ax3.text(70,65,120,'$R_{GB}=R_{BB}$',color='k',fontsize='10')
ax3.text(70,40,100,'$R^*= 44$',color='k',fontsize='10')
ax3.text(40,67,100,'$R^*= 44$',color='k',fontsize='10')
ax3.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax3.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax3.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax3.set_zlim([100, 310])
ax3.set_zticks(np.arange(100, 310, 50))
ax3.set_xlim([0, 70])
ax3.set_xticks(np.arange(0, len(cost_surface[0]), 10))
ax3.set_ylim([0, 70])
ax3.set_yticks(np.arange(0, len(cost_surface[0]), 5))
ax3.set_ylabel('\n\nR in Bad Bin ($R_{BB}$)',fontsize='9')
ax3.set_xlabel('\nR in Good Bin ($R_{GB}$)',fontsize='9')
ax3.yaxis._axinfo["grid"]['linewidth'] = 0.5
ax3.yaxis._axinfo["grid"]['linestyle'] = ":"
ax3.xaxis._axinfo["grid"]['linewidth'] = 0.5
ax3.xaxis._axinfo["grid"]['linestyle'] = ":"
ax3.zaxis._axinfo["grid"]['linewidth'] = 0.5
ax3.zaxis._axinfo["grid"]['linestyle'] = ":"
ax3.view_init(50,30)
ax3.set_proj_type('ortho')

plt.savefig(path+'Fig 62, Cost Surface');

# %% [markdown]
# ## Figure 4.4: Cross sections of costs and efficiency indexes for BE = 35. [2x3 panels]

# %%
block, checks = 20000, 5
OCD = [30,57,35]
BE = np.arange(0,71)
RGB = np.arange(0,71)
RBB = np.arange(0,71)

ex_v = np.zeros(len(RGB))
ex_a = np.zeros(len(RGB))

for rgb in RGB:
    rbb = rgb
    converged, passed = False, 0
    DD1 = np.zeros(agents+1)
    DD2 = np.zeros(agents+1)
    criminal_opps = Criminal_opps(ḡ,σ,agents,block)
    v_t, a_t, g_t, r_t = Crackdown(criminal_opps,OCD[2], rgb, rbb,F,Z)
    v, a, g, r = 0, 0, 0, 0
    v = np.append(v, v_t)
    a = np.append(a, a_t)
    g = np.append(g, g_t)
    r = np.append(r, r_t)
    for i in v:
        DD1[i] = DD1[i] + 1
    while not converged:
        criminal_opps = Criminal_opps(ḡ,σ,agents,block)
        v_t, a_t, g_t, r_t = Crackdown(criminal_opps,OCD[2], rgb, rbb,F,Z)
        v = np.append(v, v_t)
        a = np.append(a, a_t)
        g = np.append(g, g_t)
        r = np.append(r, r_t)
        for i in v:
            DD2[i] = DD2[i] + 1    
        if np.abs(np.sum((DD2/np.sum(DD2)) - (DD1/np.sum(DD1)))) < C:
            passed = passed + 1
            if passed > checks:
                converged = True
        DD1 = DD2
    DD1 = DD1/np.sum(DD1)
    ex_v[rgb] = np.mean(v)
    ex_a[rgb] = np.mean(a)

np.save(path+'fig63v_panel4.npy', ex_v)
np.save(path+'fig63a_panel4.npy', ex_a)

# %%
block, checks = 20000, 5
OCD = [30,57,35]
BE = np.arange(0,71)
RGB = np.arange(0,71)
RBB = np.arange(0,71)

ex_v = np.zeros(len(RGB))
ex_a = np.zeros(len(RGB))

for rgb in RGB:
    rbb = 57
    converged, passed = False, 0
    DD1 = np.zeros(agents+1)
    DD2 = np.zeros(agents+1)
    criminal_opps = Criminal_opps(ḡ,σ,agents,block)
    v_t, a_t, g_t, r_t = Crackdown(criminal_opps,OCD[2], rgb, rbb,F,Z)
    v, a, g, r = 0, 0, 0, 0
    v = np.append(v, v_t)
    a = np.append(a, a_t)
    g = np.append(g, g_t)
    r = np.append(r, r_t)
    for i in v:
        DD1[i] = DD1[i] + 1
    while not converged:
        criminal_opps = Criminal_opps(ḡ,σ,agents,block)
        v_t, a_t, g_t, r_t = Crackdown(criminal_opps,OCD[2], rgb, rbb,F,Z)
        v = np.append(v, v_t)
        a = np.append(a, a_t)
        g = np.append(g, g_t)
        r = np.append(r, r_t)
        for i in v:
            DD2[i] = DD2[i] + 1    
        if np.abs(np.sum((DD2/np.sum(DD2)) - (DD1/np.sum(DD1)))) < C:
            passed = passed + 1
            if passed > checks:
                converged = True
        DD1 = DD2
    DD1 = DD1/np.sum(DD1)
    ex_v[rgb] = np.mean(v)
    ex_a[rgb] = np.mean(a)

np.save(path+'fig63v_panel5.npy', ex_v)
np.save(path+'fig63a_panel5.npy', ex_a)

# %%
block, checks = 20000, 5
OCD = [30,57,35]
BE = np.arange(0,71)
RGB = np.arange(0,71)
RBB = np.arange(0,71)

ex_v = np.zeros(len(RGB))
ex_a = np.zeros(len(RGB))

for rbb in RBB:
    rgb = 30
    converged, passed = False, 0
    DD1 = np.zeros(agents+1)
    DD2 = np.zeros(agents+1)
    criminal_opps = Criminal_opps(ḡ,σ,agents,block)
    v_t, a_t, g_t, r_t = Crackdown(criminal_opps,OCD[2], rgb, rbb,F,Z)
    v, a, g, r = 0, 0, 0, 0
    v = np.append(v, v_t)
    a = np.append(a, a_t)
    g = np.append(g, g_t)
    r = np.append(r, r_t)
    for i in v:
        DD1[i] = DD1[i] + 1
    while not converged:
        criminal_opps = Criminal_opps(ḡ,σ,agents,block)
        v_t, a_t, g_t, r_t = Crackdown(criminal_opps,OCD[2], rgb, rbb,F,Z)
        v = np.append(v, v_t)
        a = np.append(a, a_t)
        g = np.append(g, g_t)
        r = np.append(r, r_t)
        for i in v:
            DD2[i] = DD2[i] + 1    
        if np.abs(np.sum((DD2/np.sum(DD2)) - (DD1/np.sum(DD1)))) < C:
            passed = passed + 1
            if passed > checks:
                converged = True
        DD1 = DD2
    DD1 = DD1/np.sum(DD1)
    ex_v[rbb] = np.mean(v)
    ex_a[rbb] = np.mean(a)
    print(rbb,rgb, end='\r')

np.save(path+'fig63v_panel6.npy', ex_v)
np.save(path+'fig63a_panel6.npy', ex_a)

# %% [markdown]
# ## Visualization

# %%
panel_4v = np.load(path+'fig63v_panel4.npy')
panel_4a = np.load(path+'fig63a_panel4.npy')
panel_5v = np.load(path+'fig63v_panel5.npy')
panel_5a = np.load(path+'fig63a_panel5.npy')
panel_6v = np.load(path+'fig63v_panel6.npy')
panel_6a = np.load(path+'fig63a_panel6.npy')
R = np.arange(len(panel_1))

'''produce series for panels 1 - 3'''
panel_1 = np.zeros(len(RGB_equals_RBB))
panel_1[:] = RGB_equals_RBB[:]
panel_2 = np.zeros(len(BE2))
panel_2[:] = BE2[35,:]
panel_3 = np.zeros(len(BE1))
panel_3[:] = BE1[35,:]

'''produce series for panels 4 - 6'''
panel_4_excap = np.zeros(len(panel_4v))
panel_4_apprate = np.zeros(len(panel_4v))
panel_5_excap = np.zeros(len(panel_5v))
panel_5_apprate = np.zeros(len(panel_5v))
panel_6_excap = np.zeros(len(panel_6v))
panel_6_apprate = np.zeros(len(panel_6v))

for r in R:
    panel_4_excap[r] = np.max([(r-panel_4v[r])/r,0])
    panel_4_apprate[r] = (panel_4a[r]/panel_4v[r])
    panel_5_excap[r] = np.max([(r-panel_5v[r])/r,0])
    panel_5_apprate[r] = (panel_5a[r]/panel_5v[r])
    panel_6_excap[r] = np.max([(r-panel_6v[r])/r,0])
    panel_6_apprate[r] = (panel_6a[r]/panel_6v[r])

fig = plt.figure(dpi=150)
gs = fig.add_gridspec(2, 3)
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[0, 2])
ax4 = fig.add_subplot(gs[1, 0])
ax5 = fig.add_subplot(gs[1, 1])
ax6 = fig.add_subplot(gs[1, 2])

ax1.set_title('Panel 1: Expected costs for $R_{GB}=R_{BB}$', fontsize='medium')
ax1.set_xticks(np.arange(0,len(panel_1),10))
ax1.set_xlim([0,len(panel_1)])
ax1.set_ylim([np.min(panel_1)-20,np.max(panel_1)+20])
ax1.set_ylabel('Expected Cost')
ax1.set_xlabel('Deterrent Resources (R)')
ax1.plot(panel_1, color='k', linestyle='solid',linewidth=1)
ax1.vlines(x=44, ymin=120, ymax=panel_1[44], linestyle='dotted')
ax1.text(46,140, '$R^*=44$', fontsize=10)
ax1.text(40,300, '$E(C|R=R_{GB}=R_{BB})$', fontsize=10)

ax2.set_title('Panel 2: Expected costs for $R_{BB}=57$', fontsize='medium')
ax2.set_xticks(np.arange(0,len(panel_2),10))
ax2.set_xlim([0,len(panel_2)])
ax2.set_ylim([np.min(panel_2)-20,np.max(panel_2)+20])
ax2.set_ylabel('Expected Cost')
ax2.set_xlabel('Deterrent Resources GB ($R_{GB}$)')
ax2.plot(panel_2, color='k', linestyle='solid',linewidth=1)
ax2.vlines(x=np.argmin(panel_2), ymin=np.min(panel_2)-20, ymax=panel_2[np.argmin(panel_2)], linestyle='dotted')
ax2.text(np.argmin(panel_2)+2,120, '$R^*=30$', fontsize=10)
ax2.text(10,240, '$E(C|R=R_{GB}=R_{BB})$', fontsize=10)

ax3.set_title('Panel 3: Expected costs for $R_{GB}=30$', fontsize='medium')
ax3.set_xticks(np.arange(0,len(panel_3),10))
ax3.set_xlim([0,len(panel_3)])
ax3.set_ylim([np.min(panel_3)-20,np.max(panel_3)+20])
ax3.set_ylabel('Expected Cost')
ax3.set_xlabel('Deterrent Resources BB ($R_{BB}$)')
ax3.plot(panel_3, color='k', linestyle='solid',linewidth=1)
ax3.vlines(x=np.argmin(panel_3), ymin=np.min(panel_3)-20, ymax=panel_3[np.argmin(panel_3)], linestyle='dotted')
ax3.text(np.argmin(panel_3)+2,120, '$R^*=57$', fontsize=10)
ax3.text(42,280, '$E(C|R=R_{GB}=R_{BB})$', fontsize=10)

ax4.set_title('Panel 4: Ex. capacity, apprehension rate for $R_{BB}=R_{GB}$', fontsize='medium')
ax4.set_xticks(np.arange(0,len(panel_4_excap),10))
ax4.set_yticks(np.arange(0,1,0.1))
ax4.set_xlim([0,len(panel_4_excap)])
ax4.set_ylim([-0.01,1])
ax4.set_ylabel('Rate')
ax4.set_xlabel('Deterrent Resources ($R=R_{GB}=R_{BB}$)')
ax4.plot(panel_4_excap, color='k', linestyle='solid',linewidth=1, label='Excess capacity')
ax4.plot(panel_4_apprate, color='k', linestyle='dashed',linewidth=1, label='Apprehension rate')
ax4.legend(loc='best', fontsize=10, frameon=False)

ax5.set_title('Panel 5: Ex. capacity, apprehension rate for $R_{BB}=57$', fontsize='medium')
ax5.set_xticks(np.arange(0,len(panel_5_excap),10))
ax5.set_yticks(np.arange(0,1,0.1))
ax5.set_xlim([0,len(panel_5_excap)])
ax5.set_ylim([-0.01,1])
ax5.set_ylabel('Rate')
ax5.set_xlabel('Deterrent Resources ($R_{GB}$)')
ax5.plot(panel_5_excap, color='k', linestyle='solid',linewidth=1, label='Excess capacity')
ax5.plot(panel_5_apprate, color='k', linestyle='dashed',linewidth=1, label='Apprehension rate')
ax5.legend(loc='best', fontsize=10, frameon=False)

ax6.set_title('Panel 4: Ex. capacity, apprehension rate for $R_{GB}=30$', fontsize='medium')
ax6.set_xticks(np.arange(0,len(panel_6_excap),10))
ax6.set_yticks(np.arange(0,1,0.1))
ax6.set_xlim([0,len(panel_6_excap)])
ax6.set_ylim([-0.01,1])
ax6.set_ylabel('Rate')
ax6.set_xlabel('Deterrent Resources ($R_{BB}$)')
ax6.plot(panel_6_excap, color='k', linestyle='solid',linewidth=1, label='Excess capacity')
ax6.plot(panel_6_apprate, color='k', linestyle='dashed',linewidth=1, label='Apprehension rate')
ax6.legend(loc='best', fontsize=10, frameon=False);

plt.savefig(path+'Fig 63, Indices');

# %% [markdown]
# ## Figure A.2:The “Cliff” with constant opportunities $g_i^t$ = $g_i$ $\forall$ $t$. [1 panel]

# %%
"""
        Fig 2: visualizing the cliff
            Note: 
"""
block = 10000
agents, Z = 100, 2
R_low, R_high = 0, agents+1

v_μ = np.zeros(R_high-R_low)
criminal_opps = Criminal_opps(ḡ,σ,agents,block)

for r in range(R_low,R_high):
    converged, passed = False, 0
    DD1 = np.zeros(agents+1)
    DD2 = np.zeros(agents+1)
    v_t, a_t, g_t = Simulation(criminal_opps,r,F,Z)
    v, a, g = 0, 0, 0
    v = np.append(v, v_t)
    a = np.append(a, a_t)
    g = np.append(g, g_t)
    for i in v:
        DD1[i] = DD1[i] + 1
    while not converged:
        v_t, a_t, g_t = Simulation(criminal_opps,r,F,Z)
        v = np.append(v, v_t)
        a = np.append(a, a_t)
        g = np.append(g, g_t)
        for i in v:
            DD2[i] = DD2[i] + 1    
        if np.abs(np.sum((DD2/np.sum(DD2)) - (DD1/np.sum(DD1)))) < C:
            passed = passed + 1
            if passed > checks:
                converged = True
        DD1 = DD2
    DD1 = DD1/np.sum(DD1)
    v_μ[r] = np.mean(v)
    
np.save(path+'figA2_mean_v.npy', v_μ)

# %%
v_μ = np.load(path+'fig52_mean_v.npy')   
v_μ_constant = np.load(path+'figA2_mean_v.npy')
x = np.arange(R_low,len(v_μ))

fig, ax1 = plt.subplots(figsize=(10,6),tight_layout=True,dpi=150)
plt.xlabel('Deterrent resources (R)', fontsize= 'medium')
ax1.set_title('Panel 1: Expected violations, constant violation opportunities', fontsize= 'small')
ax1.set(ylabel='Number of violators')
ax1.yaxis.label.set_size(11)
ax1.set_xticks(np.arange(0,R_high,10))
ax1.set_yticks(np.arange(0, R_high+2,10))
ax1.set_xlim([R_low, R_high])
ax1.set_ylim([0, agents+2])
ax1.plot(x, v_μ, color='k', linestyle='solid',linewidth=0.75, label=r'$E(v|R)$ simulated from baseline')
ax1.plot(x, v_μ_constant, color='k', linestyle='dashed',linewidth=0.75, label='$E(v|R)$ simulated for fixed $\phi(g)$')
ax1.legend(loc='best', fontsize=9, frameon=False)

plt.savefig(path+);
